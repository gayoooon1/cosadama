# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup
import openpyxl

excel_file = openpyxl.Workbook()
excel_file.remove(excel_file.active)
excel_sheet = excel_file.create_sheet('사회뉴스')  # sheet 이름 작성 
excel_sheet.column_dimensions['B'].width = 100   # 컬럼 크기 정하기 

excel_sheet.append(['번호','제목']) #sheet에 표제목 넣기 

titleli=[]
for pgnum in range(1,6):
    url = 'https://www.hankookilbo.com/News/Society/HC01?Page='
    page = urlopen(url+str(pgnum))
    soup = BeautifulSoup(page, "html.parser")

    titles = soup.find_all('p', class_='title')   # 각 타이틀에서 p 중 class가 title인 것 가져오기 
    for title in titles: 
            value=title.get_text()  # 타이틀 개수와 타이틀 내용 
            titleli.append(value)

for index in range(len(titleli)):
    excel_sheet.append([index+1, titleli[index]])
    
cell_A1 = excel_sheet['A1']
cell_A1.alignment = openpyxl.styles.Alignment(horizontal="center")  # A1 양식 center로!
cell_B1 = excel_sheet['B1']
cell_B1.alignment = openpyxl.styles.Alignment(horizontal="center")  # B1 양식 center로!

excel_file.save('한국일보 사회뉴스 타이틀 크롤링 (1~5쪽).xlsx')
excel_file.close()

# %%
import openpyxl

excel_file = openpyxl.load_workbook('C:\\Users\\Owner\\Documents\\DataScience\\COSADAMA\\source_code\\WEEK4\\한국일보 사회뉴스 타이틀 크롤링 (1~5쪽).xlsx')
excel_sheet = excel_file.active


for row in excel_sheet.rows:
    print(row[0].value, row[1].value)  # row의 첫번째, 두번째 칼럼 추출

excel_file.close()
# Out:
# 번호 제목
# 1 경찰, 오세훈 유세차량에 흉기들고 접근한 50대 영장신청
# 2 [속보] ‘해열제 입국’ 미국 유학생 오늘 고발
# 3 “투표 인증, 이번엔 손등 도장 대신 확인증으로” 왜?
# 4 31번 환자 발생 52일만에… 대구 코로나 확진자 ‘0명’으로
# 5 “오소리야 잘 살아”.. 탈진 오소리, 치료 받고 자연으로
# 6 검찰, 신라젠 전 대표 2명 구속영장…정치권 개입 의혹도 밝혀질까
# 7 [속보] 코로나 신규 확진자 27명… 대구는 없었다
# 8 “여의도 윤중로 안가요”.. 인근 17개 버스노선 우회 운행
# 9 스타벅스 매일 가야했나… 자가 격리 위반한 20대
# 10 [삶도] ‘남민전의 전사’ 홍세화가 말하는 한국이 ‘폭력의 지뢰밭’ 된 이유
# 11 “돈 줘, 독방으로 옮겨줄게”.. 수감자 돈 받은 변호사 집유 확정
# 12 교회는 막고, 룸살롱은 안막았다? 개신교인들이 뿔난 이유
# 13 대구시 의료진 수당 논란 재점화? 장관 보좌관 “지침에 없다”
# 14 코로나 유탄 맞은 일본 유흥가 ‘화상 서비스’ 등장
# 15 [단독] 향군상조회 위원장 돌연 교체, 짙어지는 의혹
# 16 [클릭! 자치뉴스]
# 17 박사방 부따 구속…법원 “범행수법 치밀하고 계획적”
# 18 채널A “취재윤리 위반 송구…지시는 없었다”
# 19 보문동의 마스크 기적… 주민 수만큼 1만6000개 제작
# 20 또래 여학생 집단 성폭행 남중생 2명 구속
# 21 교육부 “학원에서 학교 원격수업 들으면 불법”
# 22 뺨 때리고 흉기 난동까지… 폭력에 위협당하는 총선
# 23 수능 대리 응시자 사진 달랐지만…감독관들 "몰랐다"
# 24 자가격리 기간 출근한 약사ㆍ약국 직원... 검찰, 불구속 기소
# 25 온라인 수업 20분만에 나온 아들 "대화창 비속어로 수업 중단"
# 26 "대구 위해 밤낮 고생했는데…" 받을 돈 못 받은 의료진·업체들
# 27 [영상] “선생님 소리 들려요?”... 조마조마 온라인 개학 첫날
# 28 “유흥업소 중심 ‘조용한 전파’ … 안심 못 한다”
# 29 삼성SDI 울산공장에 노조 설립… 한국노총 가입
# 30 강남구 “집에 있었다” 허위 진술 유흥업소 직원 고발
# 31 코로나 10명 검체 함께 검사한다… "시간 단축 될 듯"
# 32 [포토] 조주빈 공범 '부따' 출석
# 33 195만 중국인 한국 비자 정지…진단서 있어야 재발급
# 34 [포토] 한산한 경주 황리단길
# 35 총선 앞둔 정치권, 대학 등록금 반환 목소리에 숟가락
# 36 대구시 신천지 위장 의심 단체 비영리단체 등록 말소
# 37 '쌍방향 수업' 권장했지만…교사들 "그냥 단방향 수업 할래요"
# 38 檢, 여성 신도 8년간 ‘그루밍 성폭력’ 목사에 구속영장
# 39 [포토] 오세훈 유세현장에 나타난 흉기든 괴한
# 40 [포토] 첫 공판 마친 장제원 아들
# 41 코로나 영웅이라더니 수당 미지급? 정부 “대구시와 상의해 조치”
# 42 n번방 등 성범죄자 221명 검거…3명 중 1명은 10대
# 43 ‘자가격리 스트레스 호소’ 20대 교환학생 숨진 채 발견
# 44 [포토] 태극마크 마스크 쓴 '이 시대의 영웅'
# 45 대법 “전기 쇠꼬챙이로 개 도축하면 유죄”
# 46 “매달 세월호 침몰시켜 일자리 창출” 통합당 후보 과거발언 도마에
# 47 장군님 시원하시죠? 봄맞이 목욕
# 48 “‘성 착취’ 추적 피해보다 언론·국회 때문에 힘들었다”
# 49 [영상] "한국 코로나 대응, 나만 신기해?"  국내 거주 외국인의 반응
# 50 서울아산병원에서 코로나19 치료 받던 70대 사망
# 51 오세훈 유세 현장서 흉기난동 부린 50대 남성 경찰에 체포
# 52 서울시 “확진자 나온 강남 유흥업소 고객장부 조사”
# 53 “학생은 이동 중에 ‘출첵’, 교실엔 선생님 목소리만…”
# 54 탁현민 “코로나 응원 릴레이, 간호사관생도 요청에 BTS 단번에 수락”
# 55 제주 서귀포 해상서 어선 화재로 2명 숨져
# 56 대구서 유세차 올라 후보 밀치고 운동원 폭행한 50대
# 57 청주 코로나19 완치자 2명 재확진
# 58 ‘단군 이래 최대 금융사기’ 장영자 징역 4년 확정
# 59 경찰 “윤석열 부인 수사자료 인터넷언론에 넘긴 경찰관 수사”
# 60 제주 서귀포 해상 어선 화재… 승선원 6명 구조
# 61 대전서도 코로나19 완치 후 첫 재확진자 발생
# 62 코로나19 신규 확진자 39명… 완치자 197명 늘어
# 63 법무부, 등록외국인 체류기간 3개월 직권 연장
# 64 화면으로 만나는 선생님과 친구들
# 65 선임병 부탁에 수능 대리시험 본 현역 병사… 軍 수사
# 66 "더 큰 확산 막아야" 스스로 동선 공개한 美 유학생
# 67 서귀포 남쪽 해상서 선박 전소…선원 2명 의식 없어
# 68 코로나 역학조사서 거짓말 한 사람들, 어떻게 되나
# 69 [뷰엔] 세계가 주목한 4.8g… 코로나 진단키트 생산 현장
# 70 수도권서 2차 대유행 가능성…이번 주말 최대 고비
# 71 생후 45일에 코로나19 확진 아기 38일 만에 퇴원
# 72 목포지청, 마스크 판매 사기 20대 3명 구속기소
# 73 조주빈 쫓던 ‘디지털 장의사’, 음란사이트 운영 방조 혐의 기소
# 74 “튤립 보며 잠시라도 시름 잊길”, 지친 의료진 달래준 깜짝 튤립 선물
# 75 구리시 지역사회 감염 ‘0명’… 정부보다 열흘 먼저ㆍ3중 방역 덕분
