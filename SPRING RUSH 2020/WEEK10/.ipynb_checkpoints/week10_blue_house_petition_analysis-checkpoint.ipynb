# %% [markdown]
# ## 🦉 COSADAMA Project. Blue House Petition Analysis

# %% [markdown]
# ### 1. Urllib & BeautifulSoup 이용해 데이터 가져오기

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www1.president.go.kr/petitions/answer'
html = urlopen(url)

soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"/>
# <meta content="#082e59" name="theme-color"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="description">
# <meta content="청와대, 대통령비서실, 대통령, 한국, 대한민국, 대한민국 정부, president.go.kr, 靑瓦臺, 19대, 문재인" name="keywords">
# <meta content="청와대 (CHEONGWADAE)" name="author">
# <meta content="telephone=no" name="format-detection">
# <meta content="website" property="og:type"/>
# <meta content="답변된 청원 목록 1페이지 &gt;  대한민국 청와대" property="og:title"/>
# <meta content="https://www1.president.go.kr/petitions/answer?page=1" property="og:url"/>
# <meta content="대한민국 청와대" property="og:site_name"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." property="og:description"/>
# <meta content="http://www.president.go.kr/css/favicon_400x210.png" property="og:image"/>
# <meta content="https://www1.president.go.kr/petitions/answer?page=1" name="twitter:url"/>
# <meta content="나라를 나라답게, 국민과 함께 갑니다." name="twitter:description">
# <meta content="http://www.president.go.kr/css/favicon_400x210.png" name="twitter:image"/>
# <meta content="A4YCQihzy88Col-c_8IsuKMjtJS0XM4kKQe2yq35_NI" name="google-site-verification">
# <link href="/css/favicon.ico" rel="shortcut icon"/>
# <link href="/css/favicon.png" rel="icon"/>
# <link href="/css/favicon.png" rel="apple-touch-icon"/>
# <link href="/css/sub.css?v=3" rel="stylesheet"/>
# <link href="/css/init.css?v=3" rel="stylesheet"/>
# <link href="/css/common.css" rel="stylesheet"/>
# <link href="/css/layout.css?v=20170901" rel="stylesheet"/>
# <link href="/css/jquery.mCustomScrollbar.css" rel="stylesheet"/>
# <link href="/css/animate.min.css" rel="stylesheet"/>
# <link href="/css/board.css?v=20180730" rel="stylesheet"/>
# <link href="/css/header.css?ver=20171215" rel="stylesheet"/>
# <link href="/css/main.css" rel="stylesheet"/>
# <link href="/css/sub_petitions.css" rel="stylesheet" type="text/css">
# <link href="/css/magnific-popup.css" rel="stylesheet" type="text/css">
# <link href="/css/xeicon.min.css" rel="stylesheet" type="text/css">
# <style type="text/css">
# .clearfix {*zoom:1;}
# .clearfix {content:' '; clear:both;overflow:hidden;}
# .pull-left {float: left!important;}
# .pull-right{float:right!important}
# body{line-height:normal;}
# .ans_contens{
# 	overflow:hidden;
# 	max-width:1280px;
# 	margin:0 auto;
# 	padding:130px 0 180px 0;
# }
# .ans_board{
# 	display: inline-block;
# 	width:100%;
# 	position: relative;
# 	margin-bottom:70px;
# 	padding-bottom:70px;
# 	border-bottom:1px dashed #ccc;
# }
#
# .ans_td1{width:60%;}
# .ans_td2{
# 	padding-top:55px;
# 	width:40%;
# }
#
# .ans_name{
# 	text-align:left;
# 	width:700px;
# }
# .ans_name a{display: block;}
# .ans_name_title{
# 	margin-bottom:15px;
# 	border-bottom:2px solid #1b2259;
# }
# .ans_name_title h3{
# 	color:#fff;
# 	font-size:16px;
# 	background-color:#1b2259;
# 	display: inline-block;
# 	padding:8px 15px;
# 	font-weight:400;
# 	margin-bottom:12px;
# 	border-radius:4px;
# }
# .ans_name_title h2, .ans_name_title h2 a{
# 	font-size:36px;
# 	color:#1b2259;
# 	line-height:44px;
# 	margin-bottom:30px;
# }
# .ans_name_title h2.TDepTitle,.ans_name_title h2.TDepTitle a {font-size:27px;}
#
# .ans_name_info{
# 	font-size:16px;
# 	color:#767676;
# 	text-align:center;
# 	display: inline-block;
# 	width:94%;
# 	padding:0 3%;
# }
# .ans_name_info li{
# 	float:left;
# 	padding:0 40px 0 35px;
# 	letter-spacing:-0.5px;
# }
# .ans_name_info_list1{
# 	background-image:url(../img/ans_icon_ar1.png);
# 	background-repeat:no-repeat;
# 	background-position:right 32px;
# }
# .ans_name_info_list2{
# 	background-image:url(../img/ans_icon_ar2.png);
# 	background-repeat:no-repeat;
# 	background-position:right 32px;
# }
# .ans_name_info_list3{
# 	background-image:url(../img/ans_icon_ar3.png);
# 	background-repeat:no-repeat;
# 	background-position:right 32px;
# }
# .ans_name_info_list4{
# 	background-repeat:no-repeat;
# 	background-position:right 32px;
# }
# .ans_list1_1{color:#9e9e9e;}
# .ans_list1_2{
# 	line-height:21px;
# 	font-weight:bold;
# 	color:#9e9e9e;
# }
# .ans_list2_1{color:#6d80a0;}
# .ans_list2_2{
# 	line-height:21px;
# 	font-weight:bold;
# 	color:#6d80a0;
# }
# .ans_list3_1{color:#34558e;}
# .ans_list3_2{
# 	line-height:21px;
# 	font-weight:bold;
# 	color:#34558e;
# }
# .ans_list4_1{color:#144daf;}
# .ans_list4_2{
# 	line-height:21px;
# 	font-weight:bold;
# 	color:#144daf;
# }
# .ans_name_info li:first-child{padding-left:0;}
# .ans_name_info li:last-child{padding-right:0;}
# .ans_name_info li span{}
#
# .ans_movie{
# 	position: relative;
# 	float:right;
# }
# .ans_movie_box{
# 	width:480px;
# 	height:270px;
# 	border-radius:10px;
# 	overflow:hidden;
# 	background-repeat:no-repeat;
# 	-webkit-background-size: cover;
# 	-moz-background-size: cover;
# 	-o-background-size: cover;
# 	background-size: cover;
# 	background-position: 50% 50%;
# }
# .ans_movie_plyBtn{
# 	position: absolute;
# 	top:40%;
# 	width:82px;
# 	left:50%;
# 	margin-left:-41px;
# }
# .ans_movie_plyBtn a{}
# .ans_movie_plyBtn a img{}
#
#
# .ans2Dep{
# 	overflow:hidden;
# 	margin-bottom:20px;
# 	width:100%;
# }
# .ans2Dep li{
# 	float:left;
# 	margin-right:15px;
# 	font-size:14px;
# 	color:#333;
# }
# .ans2DepTitle{margin-bottom:28px;}
#
#
#
# /* 유튜브사이즈 */
# .mfp-iframe-holder .mfp-content {
# 	width:auto;
# 	min-width:1200px;
# }
# .wv_thum_img img{
# 	width:480px;
# 	height:auto;
# 	margin-bottom:100px;
# 	border-radius:10px;
# 	float:right;
# }
#
# @media screen and (max-width: 1300px){
# 	.ans_contens{padding:180px 30px 180px 30px;}
# 	.wv_thum_img img{width:420px;}
# }
# @media screen and (max-width: 1280px){
# 	.ans_contens{padding:120px 30px 180px 30px;}
# 	.ans_name{width:99%;}
# 	.ans_name_title h2{
# 		font-size:27px;
# 		line-height:34px;
# 		margin-bottom:20px;
# 	}
# 	.ans_name_info{
# 		width:96%;
# 		padding:0 2%;
# 	}
# 	.ans_name_info li{
# 		padding:0 15px 0 15px;
# 		width:21%;
# 	}
# 	.ans_movie_box{
# 		height:250px;
# 		width:420px;
# 	}
# }
# @media screen and (max-width: 1220px){
# 	.ans_name_info li{width:20%;}
# }
# @media screen and (max-width: 1024px){
# 	.ans_name{}
# 	.ans_name_title{margin-bottom:10px;}
# 	.ans_name_title h2{
# 		font-size:22px;
# 		line-height:29px;
# 		margin-bottom:13px;
# 	}
# 	.ans_name_title h2.TDepTitle{
# 		font-size:22px;
# 		line-height:29px;
# 		margin-bottom:13px;
# 	}
# 	.ans_name_title h2.TDepTitle a{
# 		font-size:20px;;
# 		line-height:30px;
# 	}
# 	.ans_name_info li img{width:45%;}
# 	.ans_name_info{
# 		width:100%;
# 		padding:0%;
# 		font-size:13px;
# 	}
# 	.ans_name_info li{
# 		padding:0 14px 0 2px;
# 		width:22%;
# 	}
# 	.ans_name_info_list1{background-size:12%;}
# 	.ans_name_info_list2{background-size:12%;}
# 	.ans_name_info_list3{background-size:12%;}
# 	.ans_movie{}
# 	.ans_movie_box{
# 		width:320px;
# 		height:190px;
# 	}
# 	.mfp-content > div {width:100% !important;}
# 	.ans_movie_plyBtn{top:35%;}
#
#
# 	.ans2DepTitle{margin-bottom:28px;}
# 	.ans2Dep li{
# 		margin-right:12px;
# 		font-size:12px;
# 		width:33%;
# 		margin-bottom:5px;
# 	}
# }
# @media screen and (max-width: 800px){
# 	.ans_td1{}
# 	.ans_movie_box{width:290px;}
# 	.ans_name_title h2.TDepTitle a{
# 		font-size:20px;;
# 		line-height:30px;
# 	}
# }
# @media screen and (max-width: 768px){
# 	.tab.div4{}
# 	.tab.div4 li{width:25%;}
# 	.ans_contens{padding:70px 30px 95px 30px;}
# 	.ans_movie_box{
# 		width:245px;
# 		height:170px;
# 	}
#
# 	.mfp-iframe-holder .mfp-content{
# 		width:100%;
# 		min-width:auto;
# 	}
# 	.ans_name_title h2.TDepTitle a{
# 		font-size:20px;;
# 		line-height:30px;
# 	}
# }
# @media screen and (max-width: 414px){
# 	.ans_contens{padding:70px 15px 95px 15px;}
# 	.ans_board{
# 		margin-bottom:30px;
# 		padding-bottom:30px;
# 	}
# 	.ans_td1{
# 		display: block;
# 		width:100%;
# 	}
# 	.ans_td2{
# 		display: block;
# 		width:100%;
# 		padding-top:0;
# 	}
# 	.ans_name{}
# 	.ans_name_info{
# 		margin-bottom:20px;
# 		font-size:12px;
# 	}
# 	.ans_name_info li{
# 		padding:0 6px 0 2px;
# 		width:23%;
# 	}
# 	.ans_name_info_list1{background-position:right 26px;}
# 	.ans_name_info_list2{background-position:right 26px;}
# 	.ans_name_info_list3{background-position:right 26px;}
#
# 	.ans_movie{float:none;}
# 	.ans_movie_box{
# 		width:100%;
# 		height:216px;
# 	}
# 	.ans_name_title h3{
# 		font-size:14px;
# 		padding:5px 10px;
# 	}
# 	.mfp-content > div {height:195% !important;}
#
#
#
# 	.ans2Dep li{width:39%;}
# 	.ans_name_title h2.TDepTitle a{
# 		font-size:20px;;
# 		line-height:30px;
# 	}
# }
#
# @media screen and (max-width: 375px){
# 	.ans_movie_box{height:195px;}
#
# 	.ans_name_title h2.TDepTitle a{
# 		font-size:20px;;
# 		line-height:30px;
# 	}
# }
# @media screen and (max-width: 360px){
# 	.ans_name_info li{
# 		padding:0;
# 		width:25%;
# 	}
# 	.ans_name_info_list1{background:none;}
# 	.ans_name_info_list2{background:none;}
# 	.ans_name_info_list3{background:none;}
#
# 	.ans_movie_box{height:187px;}
#
# 	.ans_name_title h2.TDepTitle a{
# 		font-size:20px;;
# 		line-height:30px;
# 	}
#
# }
# @media screen and (max-width: 414px){
# 	.csp_box2 .txt25 .txt25_a {
# 		font-size:2em;
# 		line-height:1.4em;
# 		color:#252525;
# 		padding-top:40px;
# 	}
# 	.csp_box2 .txt25 .txt25_b {
# 		font-size:2.2em;
# 		line-height:1.4em;
# 		color:#252525;
# 	}
# 	.petition_box_bg {
#
# 	}
# 	#contents.c_sub .cs_hero {
# 		height:250px;
# 	}
# 	.csp_box2 .txt25 .txt25_c {
# 		font-size:1.3em;
# 		line-height:1.3em;
# 		color:#252525;
# 		padding:30px 20px;
# 		font-weight:500;
# 	}
# 	.board .b_list .bl_body .bl_no {
# 		display:none;
# 	}
# 	.ct_list .b_list .bl_body .bl_category {
# 		text-align:left !important;
# 		left:0;
# 	}
# 	.board .b_list .bl_body .bl_category {
# 		text-align: left;
# 	}
#
# 	.ct_list1 .b_list .bl_body .bl_category {
# 		text-align:left !important;
# 		left:0;
# 	}
#
# 	select#order {
# 		height:30px;
# 	}
# 	.ans_name_title h2.TDepTitle a{
# 		font-size:20px;;
# 		line-height:30px;
# 	}
# }
#
# .mfp-image-holder .mfp-content {
#     max-width: 87%;
# }
# .white-popup-block {
# 	position:relative;
# 	margin:0 auto;
# 	text-align:center;
# 	max-height:70vh;
# }
#
# .mfp-bottom-bar {
# 	margin-top: -39px;
# }
# .mfp-title {
# 	text-align:center;
# 	padding-right:0;
# }
# .mfp-title a {
# 	color:#fff;
# }
#
# .clearfix::after {
# display:block;visibility:hidden;clear:both;content:''
# }
# .event1 {
# 	width:100%;
# 	display:block;
# 	background:#043f77;
# 	color:#FFF;
# 	padding:10px 0;
# }
# .event2 {
# width:100%;
# 	display:block;
# 	background:#353535;
# 	color:#FFF;
# 	padding:10px 0;
# }
# #app_connect {
# 	margin: 10px 10px;
# 	padding: 10px 0;
# 	text-align: left;
# 	background-color: rgba(0, 0, 0, 0.7);
# 	border-radius: 10px;
# 	width: 95%;
# 	z-index: 1;
# 	position: fixed;
# 	bottom: 0;
# }
# #app_connect img {
# 	display: inline-block;
# 	vertical-align:middle;
# 	width: 38px;
# 	height: auto;
# 	padding-left: 20px;
# }
# #app_connect .app_btn {
# 	color: #fff;
# 	padding: 0 15px;
# 	height: auto;
# 	font-size: 14px;
# 	font-weight: 500;
# }
#
# @media  screen and (max-width: 600px){
# 	.pr_tk25 iframe{height:auto;}
# 	.ppo11{
# 		right:7%;
# 	}
# 	.ppo11 img{width:100%;}
# }
#
# .ppo11{position: fixed; top:130px; right:5%; z-index:99;}
# .ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# .ppo{
# 	display:none;
# 	position: relative;
# }
# .ppo_area{
# 	overflow:hidden;
# 	background-color:#fff;
# 	padding:1px;
# 	border:5px solid #0b2e4c;
# }
#
# .ppo .popCont{float:left;}
# .ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# .ppo_close_today{
# 	background-color:#222;
# 	color:#fff;
# 	text-align:center;
# 	padding:10px 0;
# }
# .ppo_close_today p{font-size:14px; cursor:pointer;}
# .popopen_top button{
# 	position:absolute;
# 	right:10px;
# 	top:10px;
# 	width:50px;
# 	height:20px;
# 	color:#FFF;
# 	cursor:pointer;
# 	z-index:99;
# }
#
# .kr_pop_close {
#     position: absolute;
#     top: -22px;
#     right: 0px;
#     cursor: pointer;
#     color: #fff;
#     text-align: center;
#     padding: 0px 0px;
#     letter-spacing: 0.1em;
#     text-decoration: none !important;
#     font-size: 14px;
# }
# @media (max-width:768px) {
# 	.board .b_list .bl_subject {margin-right:0px;}
# 	}
#
# 	.ppo11{position: fixed; top:130px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:550px;
# 		width:100%;
# 		height:auto;
# 	}
# 	.ppo .popCont{
# 		float:left;
# 	}
# 	.ppo .popCont.popCont1{
# 		border-right:7px solid #fff;
# }
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:10px 0;
# 	}
# 	.ppo_close_today p{
# 		font-size:14px; cursor:pointer;
# 	}
# 	.popopen_top{
# 	}
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
#
# @media (max-width:414px) {
# 	.ppo11{position: fixed; top:110px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:250px;
# 		width:100%;
# 		height:auto;
# 	}
#
# 	.ppo .popCont{float:left;}
# 	.ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:5px 0;
# 	}
# 	.ppo_close_today p{font-size:14px; cursor:pointer;}
#
# 	.popopen_top{
#
# 	}
#
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
# }
# @media screen and (max-width: 375px){
# 	.ppo11{position: fixed; top:110px; right:5%; z-index:99;}
# 	.ppo_close{position: absolute; top:7px; right:5px; cursor:pointer;}
# 	.ppo{
# 		display:none;
# 		position: relative;
# 	}
# 	.ppo_area{
# 		overflow:hidden;
# 		background-color:#fff;
# 		padding:1px;
# 		border:5px solid #0b2e4c;
# 	}
# 	.ppo_area img{
# 		max-width:250px;
# 		width:100%;
# 		height:auto;
# 	}
#
# 	.ppo .popCont{float:left;}
# 	.ppo .popCont.popCont1{border-right:7px solid #fff;}
#
# 	.ppo_close_today{
# 		background-color:#222;
# 		color:#fff;
# 		text-align:center;
# 		padding:5px 0;
# 	}
# 	.ppo_close_today p{font-size:14px; cursor:pointer;}
#
# 	.popopen_top{
#
# 	}
#
# 	.popopen_top button{
# 		position:absolute;
# 		right:10px;
# 		top:10px;
# 		width:50px;
# 		height:20px;
# 		color:#FFF;
# 		cursor:pointer;
# 		z-index:99;
# 	}
#
# 	.kr_pop_close {
# 		position: absolute;
# 		top:-22px;
# 		right:0px;
# 		cursor:pointer;
# 		color:#fff;
# 		text-align:center;
# 		padding:0px 0px;
# 		letter-spacing: 0.1em;
# 		text-decoration: none !important;
# 		font-size:14px;
# 	}
# }
# .mfp-image-holder .mfp-content {
#     max-width: 87%;
# }
# .white-popup-block {
# 	position:relative;
# 	margin:0 auto;
# 	text-align:center;
# 	max-height:70vh;
# }
#
# .mfp-bottom-bar {
# 	margin-top: -39px;
# }
# .mfp-title {
# 	text-align:center;
# 	padding-right:0;
# }
# .mfp-title a {
# 	color:#fff;
# }
#
# .clearfix::after {
# display:block;visibility:hidden;clear:both;content:''
# }
# .event1 {
# 	width:100%;
# 	display:block;
# 	background:#043f77;
# 	color:#FFF;
# 	padding:10px 0;
# }
# .event2 {
# width:100%;
# 	display:block;
# 	background:#353535;
# 	color:#FFF;
# 	padding:10px 0;
# }
# #app_connect {
# 	margin: 10px 10px;
# 	padding: 10px 0;
# 	text-align: left;
# 	background-color: rgba(0, 0, 0, 0.7);
# 	border-radius: 10px;
# 	width: 95%;
# 	z-index: 1;
# 	position: fixed;
# 	bottom: 0;
# }
# #app_connect img {
# 	display: inline-block;
# 	vertical-align:middle;
# 	width: 38px;
# 	height: auto;
# 	padding-left: 20px;
# }
# #app_connect .app_btn {
# 	color: #fff;
# 	padding: 0 15px;
# 	height: auto;
# 	font-size: 14px;
# 	font-weight: 500;
# }
# </style><script src="/js/html5.js"></script>
# <script src="/js/jquery-1.11.0.min.js"></script>
# <script src="/js/navigation.js"></script>
# <script src="/js/jquery.validate.min.js"></script>
# <script src="/js/jquery.mCustomScrollbar.js"></script>
# <script src="/js/jquery.flexslider-min.js"></script>
# <script src="/js/jquery.appear.js"></script>
# <script src="/js/moment.min.js"></script>
# <title>답변된 청원 목록 1페이지 &gt;  대한민국 청와대</title>
# </link></link></link></meta></meta></meta></meta></meta></meta></head>
# <body><div id="accessibility">
# <strong class="blind">컨텐츠바로가기</strong>
# <ul>
# <li><a href="#cont_view" onclick="scrolltop('cont_view');"><strong>본문으로 바로가기</strong></a></li>
# <li><a href="#sitemap"><strong>하단메뉴 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="wrap">
# <div class="head_navi">
# <h1 style=""><div class="sound_only">로고 배경이미지</div></h1>
# <div class="navigator_menu" style="">
# <ul class="menu" id="webNavi">
# <li class="menu_list ml0 main_logo"><a href="/" title="메인페이지로 이동"><img alt="청와대 로고" src="/images/main/logo.png" style="width:100%;"/></a></li>
# <li class="menu_list">
# <a href="/calendar">문재인 대통령</a>
# <ul class="menu_sub">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙 여사 소식</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/c/briefings">청와대 뉴스룸</a>
# <ul class="menu_sub">
# <li><a href="/2019nCoV">[특별] 코로나19 뉴스룸</a></li>
# <li><a href="/c/briefings">청와대가 전합니다</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/live-speeches">영상</a></li>
# <li><a href="/TodayShot">카드뉴스</a></li>
# <li><a href="/c/oversea-journals">세계의 시선</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/government-projects">정책정보</a>
# <ul class="menu_sub">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2019" style="line-height:20px;">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/petitions" title="국민소통 광장 새창열림">국민소통 광장</a>
# <ul class="menu_sub">
# <li><a href="/event/3rd" rel="noopener noreferrer" target="_blank" title="문재인 대통령 3주년 새창열림">문재인 대통령 3주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification" title="열린참여">열린참여</a></li>
# </ul>
# </li>
# <li class="menu_list">
# <a href="/about/roi">청와대 알림판</a>
# <ul class="menu_sub">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# </ul>
# </li>
# <li class="menu_list mr0">
# <a href="https://tour.president.go.kr">청와대 관람 신청</a>
# </li>
# <p class="main_search_icon"><button class="search_icon" id="trigger-overlay" type="button">검색창 열기</button></p>
# <div class="en_btn">
# <a href="http://english.president.go.kr" target="_blank" title="영문페이지로 새창열림">
# <span><img alt="" src="/images/main/language_icon.gif"/> English</span>
# </a>
# </div>
# </ul>
# <div class="overlay overlay-slidedown">
# <button class="overlay-close" type="button">닫기</button>
# <div class="full_search">
# <form action="/search" method="post">
# <fieldset>
# <ul class="full_search_btn">
# <li class="search_box">
# <label class="hide" for="loginid">검색창</label>
# <input id="loginid" name="query" placeholder="검색어를 입력해주세요." title="검색어입력" type="text" value=""/>
# </li>
# <li class="search_btn">
# <input type="submit" value="검색"/>
# </li>
# </ul>
# </fieldset>
# </form>
# </div>
# </div>
# <script src="/js/modernizr.custom.js"></script>
# <script src="/js/classie.js"></script>
# <script src="/js/search_btn.js"></script>
# </div>
# </div>
# <header class="" id="header">
# <div class="navigator_menu" style="display:none"></div>
# <div class="h_logo">
# <a href="/" title="메인페이지로 이동">
# <h1 class="blind">대한민국 청와대</h1>
# </a>
# </div>
# <hr/>
# <div class="h_search">
# <h2 class="blind">통합검색</h2>
# <div class="hs_btn">
# <button id="search_btn" type="button">
# <i><span class="sound_only">통합검색</span></i>
# <span class="blind">Search Btn</span>
# </button>
# </div>
# <div class="hs_wrap">
# <script>
# 				$(document).ready(function () {
# 					$('#form-search').submit(function () {
# 						var keyword = $(this).find('input[name="query"]').val();
# 						var regex = /^([a-zA-Z0-9가-힣 ]){2,}$/i;
# 						if (!regex.test(keyword)) {
# 							alert('검색어는 한글, 영문 숫자를 2글자 이상으로 입력해주세요.');
# 							return false;
# 						}
# 						return true;
# 					});
# 				});
# 			</script>
# <form action="/search" id="form-search">
# <fieldset>
# <legend>통합검색폼</legend>
# <div class="hs_group">
# <div class="hs_input">
# <label class="blind" for="hs_keyword">검색어</label>
# <input id="hs_keyword" name="query" placeholder="검색어를 입력해주세요." required="" type="text"/>
# </div>
# <button class="hs_ok" type="submit">검색</button>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <hr/>
# <div class="h_gnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="hg_btn">
# <h3>메뉴</h3>
# <button id="mainmenu_btn" type="button">
# <i><span class="sound_only">메인메뉴</span></i>
# <span class="blind">Menu Btn</span>
# </button>
# </div>
# <nav class="hg_wrap">
# <ul class="depth1">
# <li class="hg_president">
# <button type="button"><h3>문재인 대통령 <i><span class="sound_only">문재인 대통령</span></i></h3></button>
# <ul class="depth2">
# <li>
# <a href="/calendar">공개일정</a>
# </li>
# <li>
# <a href="/president-journey">걸어온길</a>
# </li>
# <li>
# <a href="/c/president-speeches">대통령의 말과 글</a>
# </li>
# <li>
# <a href="/c/first-lady-quotations">김정숙 여사 소식</a>
# </li>
# </ul>
# </li>
# <li class="hg_newsroom">
# <button type="button"><h3>청와대 뉴스룸 <i><span class="sound_only">청와대 뉴스룸</span></i></h3></button>
# <ul class="depth2">
# <li><a href="/2019nCoV">[특별] 코로나19 뉴스룸</a></li>
# <li>
# <a href="/c/briefings">청와대가 전합니다</a>
# </li>
# <li>
# <a href="/c/blue-house-stories">청와대 이야기</a>
# </li>
# <li>
# <a href="/live-speeches">영상</a>
# </li>
# <li>
# <a href="/TodayShot">카드뉴스</a>
# </li>
# <li>
# <a href="/c/oversea-journals">세계의 시선</a>
# </li>
# <li>
# <a href="/history">청와대 일기</a>
# </li>
# </ul>
# </li>
# <li class="hg_policy">
# <button type="button"><h3>정책정보 <i><span class="sound_only">정책정보</span></i></h3></button>
# <ul class="depth2">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2019" style="line-height:20px;">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li class="hg_community">
# <button type="button"><h3>국민소통 광장 <i><span class="sound_only">국민소통 광장</span></i></h3></button>
# <ul class="depth2">
# <li><a href="/event/3rd" rel="noopener noreferrer" target="_blank" title="문재인 대통령 3주년 새창열림">문재인 대통령 3주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification" title="열린참여">열린참여</a></li>
# </ul>
# </li>
# <li class="hg_cheongwadae">
# <button type="button"><h3>청와대 알림판 <i><span class="sound_only">청와대 알림판</span></i></h3></button>
# <ul class="depth2 hei325">
# <li>
# <a href="/about/roi">정보공개</a>
# </li>
# <li>
# <a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a>
# </li>
# <li>
# <a href="/about/organization">청와대 조직도</a>
# </li>
# <li>
# <a href="/budgets">세입·세출예산 운용상황</a>
# </li>
# <li>
# <a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a>
# </li>
# <li>
# <a href="/about/location?where=desk">오시는 길</a>
# </li>
# </ul>
# </li>
# <li><button onclick="location.href='https://tour.president.go.kr';" type="button"><h3>청와대 관람 신청<i style="background-position-x:0;background-position-y:50%"><span class="sound_only">청와대 관람 신청</span></i></h3></button></li>
# <li><button onclick="location.href='http://english.president.go.kr';" type="button"><h3>English<i aria-hidden="true" class="fa fa-globe" style="background:none; font-size:38px"><span class="sound_only">English</span></i></h3></button></li>
# </ul>
# </nav>
# </div>
# </header>
# <!-- haeder -->
# <div class="c_sub " id="contents">
# <section class="cs_hero newsroom" style="background-image: url('/storage/cover/petition_image_001.jpg');">
# <div class="sound_only">국민청원 사진</div>
# <div class="csh_txt">
# <h2 class="title t1 bold cw motion" data-animation="fadeInDown">국민청원</h2>
# <p class="text bold big cw motion" data-animation="fadeInDown"></p>
# </div>
# </section>
# <section class="cs_wrap" id="cont_view">
# <div class="cs_tab">
# <div class="tab div3">
# <ul>
# <li class="motion fadeInLeft visible" data-animation="fadeInLeft">
# <a href="/petitions">분야별 청원</a>
# </li>
# <li class="motion fadeInLeft visible" data-animation="fadeInLeft">
# <a href="/petitions/best">추천순</a>
# </li>
# <li class="motion fadeInLeft visible on" data-animation="fadeInLeft">
# <a class="on" href="/petitions/answer">답변된 청원</a>
# </li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# <!-- // haeder -->
# <hr/>
# <div class="clearfix">
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 176호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/588752">저희 아파트 경비아저씨의 억울함을 풀어주세요...</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 05. 11 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 06. 10 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 446,434 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 07. 08 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/SYsAAxEu9PI/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('SYsAAxEu9PI');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 175호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/588455">울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님 수줍게 클리어', '매력적이고 섹시한 00'이라고 성희롱한 남교사를 파면해 주세요.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 28 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 28 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 225,764 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 26 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/OZt4YbWayFw/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('OZt4YbWayFw');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 174호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/588340">등교 개학 시기를 미루어주시기 바랍니다.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 24 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 24 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 255,333 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 24 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/nlt--pugVDI/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('nlt--pugVDI');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 173호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587827">방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 재승인을 취소하라</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 07 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 07 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 273,513 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 05 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/HjzZmp-xgLY/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('HjzZmp-xgLY');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 172호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587624">렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 02 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 02 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 1,007,040 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 02 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/lRIWM8wEXx8/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('lRIWM8wEXx8');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 171호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587604">세월호 전면재수사</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 01 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 01 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 216,118 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 01 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/zL8l_omMkOw/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('zL8l_omMkOw');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title ans2DepTitle"><h3>청원답변 170호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587334">자가격리를 어기고 제주도 4박5일 여행.미국유학생 강남구 **번 확진자 처벌해주세요</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 27 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 26 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 207,563 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 25 ]</p></li></ol></div><div class="ans_name_title ans2DepTitle" style="border-bottom:none;"><h3>청원답변 169호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587169">수출용 코로나19 진단키트 이름을 독도로 해주세요</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 25 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 24 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 385,617 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 25 ]</p></li></ol></div>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/W1cmC6yxc-M/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('W1cmC6yxc-M');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 168호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/586926">유/아동 성착취 동영상 유통시킨 다크웹 손모씨의 미국 법무부 강제송환을 실행해주십시오.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 23 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 22 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 219,721 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/ua2jeBCYKHo/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('ua2jeBCYKHo');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title ans2DepTitle"><h3>청원답변 167호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587323">N번방 담당판사 오덕식을 판사자리에 반대,자격박탈을 청원합니다.</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 27 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 26 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 466,900 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol></div><div class="ans_name_title ans2DepTitle"><h3>청원답변 166호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587335">박사방 회원 중 여아살해모의한 공익근무요원 신상공개를 원합니다.</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 29 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 28 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 519,948 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol></div><div class="ans_name_title ans2DepTitle" style="border-bottom:none;"><h3>청원답변 165호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587130">&lt;텔레그램 n번방 사건 특별조사팀을 서지현 검사를 필두로 한 80%이상 여성 조사팀으로 만들어 주십시오&gt;</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 24 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 23 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 286,101 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol></div>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/gulgIzlOxmk/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('gulgIzlOxmk');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <!-- 청원 -->
# <div class="ans_board">
# <table style="width:100%;">
# <tr>
# <td class="ans_td1">
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 164호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/586941">민식이 법 개정을 청원합니다.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 23 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 22 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 354,857 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 20 ]</p></li></ol>
# </div>
# </td>
# <td class="ans_td2">
# <div class="ans_movie">
# <div class="ans_movie_box" style="background-image:url(https://img.youtube.com/vi/Iy_wwFk2e-M/sddefault.jpg);"></div>
# <p class="ans_movie_plyBtn">
# <a href="javascript:youtubopen('Iy_wwFk2e-M');"><img alt="동영상 보기" src="/img/b_youtube_play.png"/></a>
# </p>
# </div>
# </td>
# </tr>
# </table>
# </div><!-- ans_board 끝 -->
# <div class="paging">
# <div class="p_wrap">
# <div class="p_btn">
# <div class="p_btn"> <a class="on" href="javascript:void(0);" title="현재 페이지"><strong>1</strong></a> <a href="?page=2">2</a> <a href="?page=3">3</a> <a href="?page=4">4</a> <a href="?page=5">5</a> <a href="?page=6">6</a> <a href="?page=7">7</a> <a href="?page=8">8</a> <a href="?page=9">9</a> <a href="?page=10">10</a> </div> <div class="p_btn next"><a href="?page=11">Next</a></div> </div>
# </div>
# </div>
# </div><!-- ans_contens 끝 -->
# <script>
# function closePopupNotToday(){
# 	setCookie('notToday','Y', 1);
# 	$(".ppo").hide('fade');
# }
# function closePopup(){
# 	$(".ppo").hide('fade');
# }
# function setCookie(name, value, expiredays) {
# 	var today = new Date();
#     today.setDate(today.getDate() + expiredays);
#     document.cookie = name + '=' + escape(value) + '; path=/; expires=' + today.toGMTString() + ';'
# }
#
# function getCookie(name) {
#     var cName = name + "=";
#     var x = 0;
# 	var i = 0;
#     while ( i <= document.cookie.length ) {
#         var y = (x+cName.length);
#         if ( document.cookie.substring( x, y ) == cName ) {
#             if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 )
#                 endOfCookie = document.cookie.length;
#             return unescape( document.cookie.substring( y, endOfCookie ) );
#         }
#         x = document.cookie.indexOf( " ", x ) + 1;
#         if ( x == 0 )
#             break;
#     }
#     return "";
# }
# function closePopupNotToday(){
# 	//setCookie('notToday','Y', 1);
# 	$(".ppo").hide('fade');
# }
# function closePopup(){
# 	$(".ppo").hide('fade');
# }
#
# 	$(".ppo_close").click(function(){
# 		closePopup();
# 	});
# 	$(".ppo_close_today").click(function(){
# 		closePopupNotToday();
# 	});
# 	if (getCookie("notToday") != "Y"){
# 		$('.ppo').show('fade');
# 	} else {
# 		$('.ppo').hide('fade');
# 	}
#
#
#
# </script>
# <hr/>
# <!-- <div id="app_connect">
# 		<img src="/images/main/app_icon.png"><button class="app_btn">청와대 앱으로 보기<span class="blind">버튼</span></button>
# 	</div> -->
# <div id="sitemap">
# <button class="s_btn">사이트맵 <span class="blind">버튼</span></button>
# <div class="wrap">
# <ul class="depth1">
# <li>
# <h3>문재인 대통령
#                         <a class="blind" href="/calendar">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/calendar">공개일정</a></li>
# <li><a href="/president-journey">걸어온길</a></li>
# <li><a href="/c/president-speeches">대통령의 말과 글</a></li>
# <li><a href="/c/first-lady-quotations">김정숙 여사 소식</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 뉴스룸</h3>
# <ul class="depth2">
# <li><a href="/2019nCoV">[특별] 코로나19 뉴스룸</a></li>
# <li><a href="/c/briefings">청와대가 전합니다</a></li>
# <li><a href="/c/blue-house-stories">청와대 이야기</a></li>
# <li><a href="/live-speeches">영상</a></li>
# <li><a href="/TodayShot">카드뉴스</a></li>
# <li><a href="/c/oversea-journals">세계의 시선</a></li>
# <li><a href="/history">청와대 일기</a></li>
# </ul>
# </li>
# <li>
# <h3>정책정보
#                         <a class="blind" href="/government-projects">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="http://www.korea.kr/policy/actuallyList.do?pWise=main&amp;pWiseMain=A25" rel="noopener noreferrer" target="_blank" title="정책브리핑 새창열림">정책브리핑</a></li>
# <li><a href="/government-projects">국정과제</a></li>
# <li><a href="/GovReport2019">정부부처 업무보고</a></li>
# </ul>
# </li>
# <li>
# <h3>국민소통 광장
#                         <a class="blind" href="/petitions">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/event/3rd" rel="noopener noreferrer" target="_blank" title="문재인 대통령 3주년 새창열림">문재인 대통령 3주년</a></li>
# <li><a href="/petitions">국민청원</a></li>
# <li><a href="/2019townhall">국민과의 대화</a></li>
# <li><a href="/forums">토론방</a></li>
# <li><a href="http://epeople.go.kr" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">국민신문고</a></li>
# <li><a href="/Verification">열린참여</a></li>
# </ul>
# </li>
# <li>
# <h3>청와대 알림판
#                         <a class="blind" href="/about/roi">바로가기</a>
# </h3>
# <ul class="depth2">
# <li><a href="/about/roi">정보공개</a></li>
# <li><a href="https://dashboard.jobs.go.kr" rel="noopener noreferrer" target="_blank" title="일자리 상황판 새창열림">일자리 상황판</a></li>
# <li><a href="/about/organization">청와대 조직도</a></li>
# <li><a href="/budgets">세입·세출예산 운용상황</a></li>
# <li><a href="http://pa.go.kr/" rel="noopener noreferrer" target="_blank" title="대통령 기록관 새창열림">대통령 기록관</a></li>
# <li><a href="/about/location?where=desk">오시는 길</a></li>
# <li><a href="https://tour.president.go.kr" style="font-size:15px; color:#fff; font-weight:bold; margin-top:12px; text-decoration:none;">청와대 관람신청</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <hr/>
# <footer id="footer">
# <div class="wrap">
# <div class="f_group">
# <div class="f_logo">
# <h2 class="blind">대한민국 청와대</h2>
# </div>
# <div class="f_sns">
# <h2 class="blind">SNS 바로가기</h2>
# <ul>
# <li>
# <a href="https://www.facebook.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="페이스북 새창열림">
# <i class="fs_icon facebook"><span class="sound_only">페이스북 바로가기 </span></i><span class="blind">Facebook</span>
# </a>
# </li>
# <li>
# <a href="https://blog.naver.com/thebluehousekr" rel="noopener noreferrer" target="_blank" title="블로그 새창열림"><i class="fs_icon blog"><span class="sound_only">블로그 바로가기 </span></i><span class="blind">blog</span></a>
# </li>
# <li>
# <a href="https://twitter.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="트위터 새창열림">
# <i class="fs_icon twitter"><span class="sound_only">트위터 바로가기 </span></i><span class="blind">Twitter</span>
# </a>
# </li>
# <li>
# <a href="https://www.instagram.com/thebluehouse_kr/" rel="noopener noreferrer" target="_blank" title="인스타그램 새창열림">
# <i class="fs_icon instagram"><span class="sound_only">인스타그램 바로가기 </span></i><span class="blind">Instagram</span>
# </a>
# </li>
# <li>
# <a href="https://www.youtube.com/TheBlueHouseKR" rel="noopener noreferrer" target="_blank" title="유튜브 새창열림">
# <i class="fs_icon youtube"><span class="sound_only">유튜브 바로가기 </span></i><span class="blind">Youtube</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="f_wrap">
# <div class="f_info">
# <h2>CONTACT INFO</h2>
# <ul>
# <li>
# <i class="fi_icon call"><span class="sound_only">전화번호 </span></i>
# <p><a href="tel:02-730-5800">(+82) 02-730-5800</a></p>
# </li>
# <li>
# <i class="fi_icon email"><span class="sound_only">메일주소 </span></i>
# <p>담당자 메일 : <a href="mailto:webmaster@president.go.kr">메일보내기</a></p>
# </li>
# <li>
# <i class="fi_icon address"><span class="sound_only">청와대 주소</span></i>
# <p>03048 서울특별시 종로구 청와대로 1 대통령 비서실</p>
# </li>
# </ul>
# </div>
# <div class="f_menu">
# <div class="fm_wrap">
# <ul>
# <li><a href="/about/privacy">개인정보처리방침</a></li>
# <li><a href="/about/copyright">저작권 정책</a></li>
# <li><a href="/sitemap">사이트맵</a></li>
# <li><a href="/about/location">오시는 길</a></li>
# </ul>
# <ul>
# </ul>
# </div>
# <div class="fm_tip">
# 						해당 메일은 기능 장애 등 홈페이지 관련 문의만 접수합니다.<br/>
# 						청와대 및 정부에 대한 민원·제안 및 공익신고·고발 등은
# 						국민신문고(<a href="http://www.epeople.go.kr/" rel="noopener noreferrer" target="_blank" title="국민신문고 새창열림">www.epeople.go.kr</a>)로
# 						접수해주시길 부탁드립니다.
# 					</div>
# <ul class="footer_mark">
# <li><!-- <img alt="wa품질인증마크" src="/images/main/wa_mark.png"> --></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="f_copyright">
# 			© Office of the President. All rights reserved.
# 		</div>
# </footer>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-112394055-1"></script>
# <script src="/js/common.js" type="text/javascript"></script>
# <script src="/js/jquery.magnific-popup.min.js" type="text/javascript"></script>
# <script>
#   $(document).ready(function () {
#
#
#
# var webNavi = $('#webNavi').superfish({});
#   });
#
# function youtubopen(data) {
# 	$.magnificPopup.open({
# 		items: {
# 			src:'https://www.youtube.com/watch?v='+data
# 		},
# 		type: 'iframe',
# 		mainClass: 'mfp-fade',
# 		removalDelay: 160,
# 		preloader: false,
# 		fixedContentPos: false,
# 		closeMarkup: '<button type="button" class="mfp-close tBtn">닫기</button><div class="mfp-close cBtn" aria-hidden="true"><i class="xi-close"></i></div>',
# 		autoFocusLast: true,
# 		iframe: {
# 		  markup: '<div class="mfp-iframe-scaler">'+
# 					'<div class="mfp-close"></div>'+
# 					'<iframe class="mfp-iframe" frameborder="0" title="유투브 동영상 재생" allowfullscreen></iframe>'+
# 				  '</div>',
# 		  patterns: {
# 			youtube: {
# 			  index: 'youtube.com/',
# 			  id: 'v=',
# 			  src: '//www.youtube.com/embed/%id%?autoplay=1'
# 			}
#
# 		  },
#
# 		  srcAction: 'iframe_src',
# 		}
# 	});
# }
#
#
# $(document).on('click','.event2', function (e) {e.preventDefault();setCookie('notToday191111','Y', 1);$.magnificPopup.close();});
# $(document).on('click','.mfp-img', function (e) {e.preventDefault();$.magnificPopup.close();youtubopen('46E4TFNVvJM');});
# 	function noticeopen() {
# 		$.magnificPopup.open({
# 			items: {
# 				src:'/storage/images/2019/11/ii_k2zv5l920.png',
# 				markup:'<div class="mfp-figure">'+
# 					'<div class="mfp-close"></div>'+
# 					'<div class="mfp-img"><img src="/storage/images/2019/11/ii_k2zv5l920.png"></div>'+
# 					'<div class="mfp-bottom-bar"><div class="mfp-title" style="background:#000;"></div></div></div>',
# 				title:'<table width="100%"><tr><td><a href="javascript:void(0);" class="event2">오늘 하루 열지 않음</a></td></tr></table>'
# 			},
# 			disableOn: 700,
# 			type: 'image',
# 			mainClass: 'mfp-fade',
# 			preloader: true,
# 			fixedContentPos: true,
# 			verticalFit:true
# 		});
# 	}
#
# 	if(getCookie('notToday191111') != 'Y'){
# 		//noticeopen();
# 	}
#
#
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());gtag('config', 'UA-112394055-1');
#
# 	function scrolltop(oj){
# 		var scrollPosition = $('#'+oj).offset().top;
# 		var navPosition = $('.navigator_menu').offset().top;
#
# 		$('html, body').stop().animate({scrollTop : scrollPosition-(navPosition+30)}, 300);
# 		$('#'+oj);
# 	}
# </script>
# </body>
# </html>

# %%
lists = soup.find_all('div', class_='ans_name')
lists
# Out:
# [<div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 176호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/588752">저희 아파트 경비아저씨의 억울함을 풀어주세요...</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 05. 11 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 06. 10 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 446,434 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 07. 08 ]</p></li></ol>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 175호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/588455">울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님 수줍게 클리어', '매력적이고 섹시한 00'이라고 성희롱한 남교사를 파면해 주세요.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 28 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 28 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 225,764 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 26 ]</p></li></ol>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 174호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/588340">등교 개학 시기를 미루어주시기 바랍니다.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 24 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 24 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 255,333 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 24 ]</p></li></ol>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 173호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587827">방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 재승인을 취소하라</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 07 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 07 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 273,513 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 05 ]</p></li></ol>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 172호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587624">렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 02 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 02 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 1,007,040 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 02 ]</p></li></ol>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 171호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587604">세월호 전면재수사</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 04. 01 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 05. 01 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 216,118 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 06. 01 ]</p></li></ol>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title ans2DepTitle"><h3>청원답변 170호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587334">자가격리를 어기고 제주도 4박5일 여행.미국유학생 강남구 **번 확진자 처벌해주세요</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 27 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 26 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 207,563 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 25 ]</p></li></ol></div><div class="ans_name_title ans2DepTitle" style="border-bottom:none;"><h3>청원답변 169호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587169">수출용 코로나19 진단키트 이름을 독도로 해주세요</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 25 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 24 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 385,617 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 25 ]</p></li></ol></div>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 168호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/586926">유/아동 성착취 동영상 유통시킨 다크웹 손모씨의 미국 법무부 강제송환을 실행해주십시오.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 23 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 22 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 219,721 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title ans2DepTitle"><h3>청원답변 167호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587323">N번방 담당판사 오덕식을 판사자리에 반대,자격박탈을 청원합니다.</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 27 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 26 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 466,900 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol></div><div class="ans_name_title ans2DepTitle"><h3>청원답변 166호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587335">박사방 회원 중 여아살해모의한 공익근무요원 신상공개를 원합니다.</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 29 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 28 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 519,948 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol></div><div class="ans_name_title ans2DepTitle" style="border-bottom:none;"><h3>청원답변 165호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/587130">&lt;텔레그램 n번방 사건 특별조사팀을 서지현 검사를 필두로 한 80%이상 여성 조사팀으로 만들어 주십시오&gt;</a></h2><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 24 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 23 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 286,101 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 22 ]</p></li></ol></div>
#  </div>,
#  <div class="ans_name">
#  <!-- -->
#  <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 164호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/586941">민식이 법 개정을 청원합니다.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 23 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 22 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 354,857 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 20 ]</p></li></ol>
#  </div>]

# %%
for list in lists[:5]: 
    print(list.get_text())
# Out:
# 청원답변 176호저희 아파트 경비아저씨의 억울함을 풀어주세요...청원시작[ 2020. 05. 11 ]청원마감[ 2020. 06. 10 ]참여인원[ 446,434 ]답변일[ 2020. 07. 08 ]
#
#
#
# 청원답변 175호울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님 수줍게 클리어', '매력적이고 섹시한 00'이라고 성희롱한 남교사를 파면해 주세요.청원시작[ 2020. 04. 28 ]청원마감[ 2020. 05. 28 ]참여인원[ 225,764 ]답변일[ 2020. 06. 26 ]
#
#
#
# 청원답변 174호등교 개학 시기를 미루어주시기 바랍니다.청원시작[ 2020. 04. 24 ]청원마감[ 2020. 05. 24 ]참여인원[ 255,333 ]답변일[ 2020. 06. 24 ]
#
#
#
# 청원답변 173호방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 재승인을 취소하라청원시작[ 2020. 04. 07 ]청원마감[ 2020. 05. 07 ]참여인원[ 273,513 ]답변일[ 2020. 06. 05 ]
#
#
#
# 청원답변 172호렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요청원시작[ 2020. 04. 02 ]청원마감[ 2020. 05. 02 ]참여인원[ 1,007,040 ]답변일[ 2020. 06. 02 ]

# %%
len(lists)
# Out:
# 10

# %%
tmp_one = soup.find_all('div', class_='ans_name')[9]
#type(tmp_one)

# %%
tmp_one
# Out:
# <div class="ans_name">
# <!-- -->
# <div class="ans_name_title" style="border-bottom:none;"><h3>청원답변 164호</h3><h2 class="TDepTitle" style="margin-bottom:15px;"><a href="/petitions/586941">민식이 법 개정을 청원합니다.</a></h2></div><ol class="ans_name_info" style="margin-bottom:20px;"><li class="ans_name_info_list1"><img alt="청원시작 아이콘" src="/img/ans_icon1.png"/><p class="ans_list1_1">청원시작</p><p class="ans_list1_2">[ 2020. 03. 23 ]</p></li><li class="ans_name_info_list2"><img alt="청원마감 아이콘" src="/img/ans_icon2.png"/><p class="ans_list2_1">청원마감</p><p class="ans_list2_2">[ 2020. 04. 22 ]</p></li><li class="ans_name_info_list3"><img alt="참여인원 아이콘" src="/img/ans_icon3.png"/><p class="ans_list3_1">참여인원</p><p class="ans_list3_2">[ 354,857 ]</p></li><li class="ans_name_info_list4"><img alt="답변일 아이콘" src="/img/ans_icon4.png"/><p class="ans_list4_1">답변일</p><p class="ans_list4_2">[ 2020. 05. 20 ]</p></li></ol>
# </div>

# %%
print(tmp_one.find(class_='ans_name_title').a.get_text())
print(tmp_one.find(class_='ans_list1_2').get_text())
print(tmp_one.find(class_='ans_list2_2').get_text())
print(tmp_one.find(class_='ans_list3_2').get_text())
print(tmp_one.find(class_='ans_list4_2').get_text())
# Out:
# 민식이 법 개정을 청원합니다.
# [ 2020. 03. 23 ]
# [ 2020. 04. 22 ]
# [ 354,857 ]
# [ 2020. 05. 20 ]

# %%
tmp_one.find('a')['href']
# Out:
# '/petitions/586941'

# %%
a = tmp_one.find(class_='ans_name_title').get_text()
print(a[:9]) # 청원답변 xxx호
# type(a) 문자열임
b = tmp_one.find(class_='ans_list1_2').get_text()
print(b[2:14])
c = tmp_one.find(class_='ans_list3_2').get_text()
print(c[2:10])
# Out:
# 청원답변 164호
# 2020. 03. 23
# 354,857

# %% [markdown]
# ### 2. DataFrame에 정보 담기

# %%
pet_title = []
pet_start = []
pet_end = []
pet_ppl = []
pet_ans = []
pet_url = []
pet_ars = []

#def get_data() :
for pgn in range(1,13):
    urlbd = 'https://www1.president.go.kr/petitions/answer?page='
    pg = urlopen(urlbd + str(pgn))
    soup = BeautifulSoup(pg, "html.parser")
    tmp_x = soup.find_all('div', class_='ans_name')

    for n in range(0,len(tmp_x)):
      tmp = tmp_x[n]
      pet_title.append(tmp.find(class_='ans_name_title').a.get_text())
      # 제목만 가져와야 하기 때문에 a 추가
      # 안그러면 청원시작일 등 모든 데이터가 포함되어 나옴
      pet_start.append(tmp.find(class_='ans_list1_2').get_text()[2:-2])
      pet_end.append(tmp.find(class_='ans_list2_2').get_text()[2:-2])
      pet_ppl.append(tmp.find(class_='ans_list3_2').get_text()[2:-2])
      pet_ans.append(tmp.find(class_='ans_list4_2').get_text()[2:-2])
      pet_ars.append('https://www1.president.go.kr' + str(tmp.find('a')['href']))

data = {'제목':pet_title, '청원시작일':pet_start,
        '청원종료일':pet_end,'참여인원':pet_ppl,'청원답변일':pet_ans,'URL':pet_ars}
df = pd.DataFrame(data)
df.head()
# Out:
#                                                   제목         청원시작일  \
# 0                        저희 아파트 경비아저씨의 억울함을 풀어주세요...  2020. 05. 11
# 1  울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님...  2020. 04. 28
# 2                             등교 개학 시기를 미루어주시기 바랍니다.  2020. 04. 24
# 3  방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 ...  2020. 04. 07
# 4                       렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요  2020. 04. 02
#
#           청원종료일       참여인원         청원답변일  \
# 0  2020. 06. 10    446,434  2020. 07. 08
# 1  2020. 05. 28    225,764  2020. 06. 26
# 2  2020. 05. 24    255,333  2020. 06. 24
# 3  2020. 05. 07    273,513  2020. 06. 05
# 4  2020. 05. 02  1,007,040  2020. 06. 02
#
#                                              URL
# 0  https://www1.president.go.kr/petitions/588752
# 1  https://www1.president.go.kr/petitions/588455
# 2  https://www1.president.go.kr/petitions/588340
# 3  https://www1.president.go.kr/petitions/587827
# 4  https://www1.president.go.kr/petitions/587624

# %%
df.sort_values(by='참여인원')[:10]
# Out:
#                                             제목         청원시작일         청원종료일  \
# 4                 렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요  2020. 04. 02  2020. 05. 02
# 15  신천지 예수교 증거장막성전(이하, 신천지)의 강제 해체(해산)을 청원합니다.  2020. 02. 22  2020. 03. 23
# 14                          문재인 대통령 탄핵을 촉구합니다.  2020. 02. 04  2020. 03. 05
# 51                              자유 한국당 정당해산 청원  2019. 04. 22  2019. 05. 22
# 74              포항 약국 칼부림 사건의 가해 남성을 제대로 처벌하라.  2018. 11. 18  2018. 12. 18
# 16              텔레그램 n번방 용의자 신상공개 및 포토라인 세워주세요  2020. 03. 18  2020. 04. 17
# 96                             합정 **** 불법 누드촬영  2018. 05. 17  2018. 06. 16
# 49          진주 방화 및 살인 범죄자에 대해서 무관용 원칙이 필요합니다.  2019. 04. 18  2019. 05. 18
# 23       계엄령 문건 수사 관련, 윤석열 검찰청장에 대한 수사를 촉구합니다.  2019. 10. 24  2019. 11. 23
# 72             부하 여군을 강간한 두 명의 해군 간부를 처벌해주십시오.  2018. 11. 09  2018. 12. 09
#
#          참여인원         청원답변일                                            URL
# 4   1,007,040  2020. 06. 02  https://www1.president.go.kr/petitions/587624
# 15  1,449,521  2020. 04. 21  https://www1.president.go.kr/petitions/585290
# 14  1,469,023  2020. 04. 24  https://www1.president.go.kr/petitions/584936
# 51  1,831,900  2019. 06. 11  https://www1.president.go.kr/petitions/579682
# 74    142,715  2018. 12. 11  https://www1.president.go.kr/petitions/445550
# 16  2,715,626  2020. 03. 24  https://www1.president.go.kr/petitions/586819
# 96    201,590  2018. 05. 21  https://www1.president.go.kr/petitions/235102
# 49    202,804  2019. 06. 14  https://www1.president.go.kr/petitions/579612
# 23    205,668  2020. 01. 22  https://www1.president.go.kr/petitions/583274
# 72    206,447  2018. 12. 18  https://www1.president.go.kr/petitions/436901

# %%
df.to_csv('Blue-House-Petition-data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# [pd param thousands means...](https://stackoverflow.com/questions/37439933/pandas-reading-csv-data-formatted-with-comma-for-thousands-separator)

# %%
petition = pd.read_csv('Blue-House-Petition-data.csv', thousands=',', encoding='utf-8', index_col=0)
#천 단위로 구분해라 이말아닌교?
petition.head()
# Out:
#                                                   제목         청원시작일  \
# 0                        저희 아파트 경비아저씨의 억울함을 풀어주세요...  2020. 05. 11
# 1  울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님...  2020. 04. 28
# 2                             등교 개학 시기를 미루어주시기 바랍니다.  2020. 04. 24
# 3  방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 ...  2020. 04. 07
# 4                       렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요  2020. 04. 02
#
#           청원종료일     참여인원         청원답변일  \
# 0  2020. 06. 10   446434  2020. 07. 08
# 1  2020. 05. 28   225764  2020. 06. 26
# 2  2020. 05. 24   255333  2020. 06. 24
# 3  2020. 05. 07   273513  2020. 06. 05
# 4  2020. 05. 02  1007040  2020. 06. 02
#
#                                              URL
# 0  https://www1.president.go.kr/petitions/588752
# 1  https://www1.president.go.kr/petitions/588455
# 2  https://www1.president.go.kr/petitions/588340
# 3  https://www1.president.go.kr/petitions/587827
# 4  https://www1.president.go.kr/petitions/587624

# %%
len(petition)
# Out:
# 117

# %%
petition.index[1]
# Out:
# 1

# %%
import re 
import time
from tqdm import tqdm_notebook # PYTHON 진행표시바 만들기
from urllib.request import urlopen
from bs4 import BeautifulSoup

category =[]
content = []
answer = []
person = []

for n in tqdm_notebook(petition.index): 
    url = urlopen(petition['URL'][n]) 
    time.sleep(1)
    soup = BeautifulSoup(url, "html.parser")
    tmp_x = soup.find('ul',class_='petitionsView_info_list').get_text()
    p0 = re.compile('\s')
    splited = p0.split(tmp_x) #tmp_y.li.get_text()
    category.append(splited[1:5][0][4:]) # 카테고리 가져오기
    person.append(splited[1:5][3][3:]) # 청원인 가져오기
    
    tmp_y = soup.find_all('div',class_='View_write')
    if len(tmp_y) > 1:
        content_raw = tmp_y[1].get_text()
    else:
        content_raw = tmp_y[0].get_text()
    p1 = re.compile('\r|\t|\n|\xa0')
    content_splited = p1.split(content_raw)
    content.append(''.join(content_splited)) # 청원내용 가져오기
    
    tmp_z = soup.find_all('div', class_='pr_tk25')
    if len(tmp_z) > 1:
        ans_raw = tmp_z[1].get_text()
    else:
        ans_raw = tmp_z[0].get_text()
    ans_splited = p1.split(ans_raw)
    ans_splited = ' '.join(ans_splited)
    answer.append(ans_splited[7:]) # 청원답변 가져오기
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))

# %%
#url = urlopen(petition['URL'][26]) 
#time.sleep(1)
#soup = BeautifulSoup(url, "html.parser")

#tmp_y = soup.find_all('div',class_='View_write')
#print(tmp_y[0])
#print(len(tmp_y))
#p1 = re.compile('\r|\t|\n|\xa0')
#content_splited = p1.split(content_raw)
#content_splited
#content.append(''.join(content_splited)) # 청원내용 가져오기
    
#tmp_z = soup.find_all('div', class_='pr_tk25')
#ans_raw = tmp_z[1].get_text()
#ans_splited = p1.split(ans_raw)
#ans_splited = ' '.join(ans_splited)
#answer.append(ans_splited[7:]) # 청원답변 가져오기

# %%
print(len(category), len(content), len(answer), len(person))
# Out:
# 117 117 117 117

# %%
petition['카테고리'] = category
petition['청원내용'] = content
petition['청원답변'] = answer
petition['청원인'] = person

# %%
petition[petition['청원내용'] == '']
# Out:
#                                     제목         청원시작일         청원종료일    참여인원  \
# 96                     합정 **** 불법 누드촬영  2018. 05. 17  2018. 06. 16  201590
# 99  다산신도시 실버택배 비용은 입주민들의 관리비로 충당해야합니다.  2018. 04. 17  2018. 05. 17  302082
#
#            청원답변일                                            URL    카테고리 청원내용  \
# 96  2018. 05. 21  https://www1.president.go.kr/petitions/235102  인권/성평등
# 99  2018. 05. 04  https://www1.president.go.kr/petitions/203181      행정
#
#    청원답변    청원인
# 96       naver
# 99       naver

# %%
for n in [96,99]:
    url = urlopen(petition['URL'][n]) 
    soup = BeautifulSoup(url, "html.parser") 
    
    # get petition content 
    content_raw = soup.find_all('div', class_='View_write')
    content_raw_text = content_raw[2].get_text()
    content_split = re.split('\r|\t|\n|\xa0', content_raw_text)
    petition['청원내용'][n] = ''.join(content_split)
    
    # get petition answer 
    answer_raw = soup.find_all('div', class_='pr_tk25')
    answer_raw_text = re.split("\r|\t|\n|\xa0", answer_raw[2].get_text())
    answer_raw_text = ' '.join(answer_raw_text)
    petition['청원답변'][n] = answer_raw_text[7:]
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
petition[petition['청원내용'] == ''] # 재확인
# Out:
# Empty DataFrame
# Columns: [제목, 청원시작일, 청원종료일, 참여인원, 청원답변일, URL, 카테고리, 청원내용, 청원답변, 청원인]
# Index: []

# %%
petition.to_csv('Final-Blue-House-Petition-data.csv', sep=',', encoding='utf-8')

# %%
petition_r = pd.read_csv('Final-Blue-House-Petition-data.csv', thousands=',', encoding='utf-8', index_col=0)
petition_r.head()
# Out:
#                                                   제목         청원시작일  \
# 0                        저희 아파트 경비아저씨의 억울함을 풀어주세요...  2020. 05. 11
# 1  울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님...  2020. 04. 28
# 2                             등교 개학 시기를 미루어주시기 바랍니다.  2020. 04. 24
# 3  방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 ...  2020. 04. 07
# 4                       렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요  2020. 04. 02
#
#           청원종료일     참여인원         청원답변일  \
# 0  2020. 06. 10   446434  2020. 07. 08
# 1  2020. 05. 28   225764  2020. 06. 26
# 2  2020. 05. 24   255333  2020. 06. 24
# 3  2020. 05. 07   273513  2020. 06. 05
# 4  2020. 05. 02  1007040  2020. 06. 02
#
#                                              URL         카테고리  \
# 0  https://www1.president.go.kr/petitions/588752       인권/성평등
# 1  https://www1.president.go.kr/petitions/588455        육아/교육
# 2  https://www1.president.go.kr/petitions/588340        육아/교육
# 3  https://www1.president.go.kr/petitions/587827  문화/예술/체육/언론
# 4  https://www1.president.go.kr/petitions/587624           기타
#
#                                                 청원내용  \
# 0  안녕하세요 저는 **동 **아파트 2동에 거주한지 이제 2년째 되가는 입주민입니다....
# 1  안녕하십니까?저는 아이들의 인권이 최우선이라고 생각하며두 남매를 열심히 키우고 있는...
# 2  최근 코로나19의 신규 확진자 수가 50명 이하로 감소하였고, 정부는 등교 개학을 ...
# 3  최근 MBC의 잇따른 보도에 따르면 종편 채널A 기자가 현직 검사장과의 친분을 내세...
# 4  29일 오전 0시 1분쯤 대전 동구의 한 네거리에서 훔친 렌터카를 몰던 10대 청소...
#
#                                                 청원답변       청원인
# 0  안녕하십니까. 국토교통비서관 윤성원입니다.   안녕하십니까 고용노동비서관 조성재입니...     kakao
# 1  안녕하십니까. 청와대 교육비서관 박경미입니다.   울산의 한 초등학교 교사의 성비위...     naver
# 2  안녕하십니까. 부총리 겸 교육부 장관 유은혜입니다.   코로나19가 완전히 종식되거...     kakao
# 3  안녕하십니까. 방송통신위원회 위원장 한상혁입니다. 오늘 답변드릴 ‘채널A와 TV조선...  facebook
# 4  안녕하십니까. 디지털소통센터장 강정수입니다.   오늘은 「렌트카 훔쳐 사망사고 낸 ...  facebook

# %% [markdown]
# ### 3. EDA (Exploratory Data Analysis) 탐색적 자료 분석

# %%
import pandas as pd
import platform
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import platform 
from matplotlib import font_manager, rc 
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')

# %%
petition = pd.read_csv('Final-Blue-House-Petition-data.csv',
                       index_col=0, parse_dates=['청원시작일','청원종료일','청원답변일'])
petition.head()
# Out:
#                                                   제목      청원시작일      청원종료일  \
# 0                        저희 아파트 경비아저씨의 억울함을 풀어주세요... 2020-05-11 2020-06-10
# 1  울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님... 2020-04-28 2020-05-28
# 2                             등교 개학 시기를 미루어주시기 바랍니다. 2020-04-24 2020-05-24
# 3  방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 ... 2020-04-07 2020-05-07
# 4                       렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요 2020-04-02 2020-05-02
#
#       참여인원      청원답변일                                            URL  \
# 0   446434 2020-07-08  https://www1.president.go.kr/petitions/588752
# 1   225764 2020-06-26  https://www1.president.go.kr/petitions/588455
# 2   255333 2020-06-24  https://www1.president.go.kr/petitions/588340
# 3   273513 2020-06-05  https://www1.president.go.kr/petitions/587827
# 4  1007040 2020-06-02  https://www1.president.go.kr/petitions/587624
#
#           카테고리                                               청원내용  \
# 0       인권/성평등  안녕하세요 저는 **동 **아파트 2동에 거주한지 이제 2년째 되가는 입주민입니다....
# 1        육아/교육  안녕하십니까?저는 아이들의 인권이 최우선이라고 생각하며두 남매를 열심히 키우고 있는...
# 2        육아/교육  최근 코로나19의 신규 확진자 수가 50명 이하로 감소하였고, 정부는 등교 개학을 ...
# 3  문화/예술/체육/언론  최근 MBC의 잇따른 보도에 따르면 종편 채널A 기자가 현직 검사장과의 친분을 내세...
# 4           기타  29일 오전 0시 1분쯤 대전 동구의 한 네거리에서 훔친 렌터카를 몰던 10대 청소...
#
#                                                 청원답변       청원인
# 0  안녕하십니까. 국토교통비서관 윤성원입니다.   안녕하십니까 고용노동비서관 조성재입니...     kakao
# 1  안녕하십니까. 청와대 교육비서관 박경미입니다.   울산의 한 초등학교 교사의 성비위...     naver
# 2  안녕하십니까. 부총리 겸 교육부 장관 유은혜입니다.   코로나19가 완전히 종식되거...     kakao
# 3  안녕하십니까. 방송통신위원회 위원장 한상혁입니다. 오늘 답변드릴 ‘채널A와 TV조선...  facebook
# 4  안녕하십니까. 디지털소통센터장 강정수입니다.   오늘은 「렌트카 훔쳐 사망사고 낸 ...  facebook

# %%
petition.shape
# Out:
# (117, 10)

# %% [markdown]
# **분석에 필요한 데이터만 남기기**

# %%
petition.drop(['URL', '청원종료일','청원답변','청원인'], axis=1, inplace=True)
petition.head()
# Out:
#                                                   제목      청원시작일     참여인원  \
# 0                        저희 아파트 경비아저씨의 억울함을 풀어주세요... 2020-05-11   446434
# 1  울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님... 2020-04-28   225764
# 2                             등교 개학 시기를 미루어주시기 바랍니다. 2020-04-24   255333
# 3  방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 ... 2020-04-07   273513
# 4                       렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요 2020-04-02  1007040
#
#        청원답변일         카테고리                                               청원내용
# 0 2020-07-08       인권/성평등  안녕하세요 저는 **동 **아파트 2동에 거주한지 이제 2년째 되가는 입주민입니다....
# 1 2020-06-26        육아/교육  안녕하십니까?저는 아이들의 인권이 최우선이라고 생각하며두 남매를 열심히 키우고 있는...
# 2 2020-06-24        육아/교육  최근 코로나19의 신규 확진자 수가 50명 이하로 감소하였고, 정부는 등교 개학을 ...
# 3 2020-06-05  문화/예술/체육/언론  최근 MBC의 잇따른 보도에 따르면 종편 채널A 기자가 현직 검사장과의 친분을 내세...
# 4 2020-06-02           기타  29일 오전 0시 1분쯤 대전 동구의 한 네거리에서 훔친 렌터카를 몰던 10대 청소...

# %% [markdown]
# **카테고리 별 청원수**

# %%
petition_ctgry = petition['카테고리'].value_counts()
petition_ctgry
print(len(petition_ctgry))
# Out:
# 15

# %%
petition_ctgry.sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %% [markdown]
# ### 4. WordCloud 시각화

# %%
import nltk
from konlpy.tag import Okt
okt = Okt()

# %%
humanRights = petition[petition['카테고리'] == '인권/성평등']
humanRights.shape
# Out:
# (31, 6)

# %%
humanRights_text = ''

for each_line in humanRights['청원내용']: 
  humanRights_text = humanRights_text + each_line + '\n'

# %%
tokens_ko = okt.morphs(humanRights_text)
tokens_ko
# Out:
# ['안녕하세요',
#  '저',
#  '는',
#  '**',
#  '동',
#  '**',
#  '아파트',
#  '2',
#  '동',
#  '에',
#  '거주',
#  '한지',
#  '이제',
#  '2년',
#  '째',
#  '되가는',
#  '입',
#  '주민',
#  '입니다',
#  '.',
#  '주택',
#  '에서만',
#  '쭉',
#  '살다가',
#  '물',
#  '좋고',
#  '공기',
#  '좋은',
#  '이',
#  '곳',
#  '에',
#  '와서',
#  '행복한',
#  '나날',
#  '을',
#  '보내던',
#  '중',
#  '어제',
#  '정말',
#  '허망',
#  '하고',
#  '억울한',
#  '소식',
#  '을',
#  '들었습니다',
#  '.',
#  '저희',
#  '아파트',
#  '경비',
#  '아저씨',
#  '가',
#  '주차',
#  '문제',
#  '로',
#  '인해',
#  '4월',
#  '말부터',
#  '20일',
#  '정도',
#  '말로',
#  '설명',
#  '할',
#  '수',
#  '없이',
#  '힘든',
#  '폭언',
#  '으로',
#  '인해',
#  '생',
#  '을',
#  '마감',
#  '하셨다는',
#  '소식',
#  '이',
#  '였습니다',
#  '...',
#  '정말',
#  '좋으신',
#  '분이셨습니다',
#  '.',
#  '처음',
#  '이사',
#  '와',
#  '서',
#  '저',
#  '한테',
#  '아니',
#  '입',
#  '주민',
#  '들',
#  '에게',
#  '매번',
#  '잘',
#  '해주시고',
#  '자기',
#  '가족',
#  '인',
#  '것',
#  '처럼',
#  '자기',
#  '일인',
#  '것',
#  '처럼',
#  '매번',
#  '아파트',
#  '주민',
#  '분들',
#  '을',
#  '위해',
#  '희생',
#  '하시는',
#  '성실한',
#  '분이셨습니다',
#  '..',
#  '같이',
#  '깨끗하게',
#  '살아야한',
#  '다',
#  '면서',
#  '아파트',
#  '안쪽',
#  '청소',
#  '도',
#  '모자라',
#  '아파트',
#  '밖',
#  '까지',
#  '청소',
#  '하시는',
#  '정말',
#  '열심히',
#  '사시',
#  '는',
#  '분이셨습니다',
#  '..',
#  '아침',
#  '마다',
#  '먼저',
#  '오셔서',
#  '안녕하세',
#  '유라',
#  '며',
#  '먼저',
#  '인사',
#  '해주시는',
#  '힘든',
#  '출근길',
#  '에',
#  '웃음',
#  '을',
#  '주시',
#  '는',
#  '비타민',
#  '같은',
#  '존',
#  '재셨습니다',
#  '.',
#  '그래서',
#  '처음',
#  '아파트',
#  '에',
#  '살',
#  '아',
#  '보면서',
#  '불편하다고',
#  '생각',
#  '이',
#  '하나',
#  '도',
#  '안',
#  '들',
#  '정도',
#  '로',
#  '잘',
#  '해주셨고',
#  '대학생',
#  '딸',
#  '분',
#  '이야기',
#  '하시면서',
#  '저',
#  '도',
#  '딸',
#  '같이',
#  '생각',
#  '이',
#  '드셨는지',
#  '공주',
#  '님',
#  '이라고',
#  '칭',
#  '해주시면서',
#  '엄청',
#  '챙겨주시고',
#  '예뻐',
#  '해주시',
#  '고',
#  '귀여워',
#  '해주시던',
#  '아저씨',
#  '생각',
#  '하니',
#  '눈물',
#  '이',
#  '앞',
#  '을',
#  '가립니다',
#  '..',
#  '처음',
#  '에는',
#  '공주',
#  '님',
#  '이라는',
#  '칭호',
#  '가',
#  '부담스러워서',
#  '좀',
#  '이상하',
#  '신분',
#  '인가',
#  '오해',
#  '했던',
#  '제',
#  '가',
#  '너무',
#  '죄송하네요',
#  '..',
#  '그만큼',
#  '엄청',
#  '좋으신',
#  '분이셨단',
#  '겁니다',
#  '..',
#  '근데',
#  '주차장',
#  '이',
#  '협소합니',
#  '다',
#  '두',
#  '동',
#  '밖',
#  '에',
#  '없어서',
#  '인지',
#  '많이',
#  '협소',
#  '하긴',
#  '합니다',
#  '..',
#  '주차',
#  '를',
#  '하기',
#  '위해',
#  '주말',
#  '이면',
#  '여러',
#  '번',
#  '뱅뱅',
#  '돌아',
#  '야하는',
#  '고충',
#  '이',
#  '있습니다',
#  '.',
#  '그',
#  '주차',
#  '문',
#  '제',
#  '때문',
#  '에',
#  '일이',
#  '벌어졌더군요',
#  '...',
#  '이중주',
#  '차로',
#  '인해서',
#  '자',
#  '기차',
#  '를',
#  '밀었다고',
#  '사람',
#  '을',
#  '죽여',
#  '버리겠다고',
#  '협박',
#  '을',
#  '하고',
#  '근무시간',
#  '마다',
#  '와서',
#  '때리고',
#  '욕',
#  '하고',
#  '씨',
#  '씨',
#  '티비',
#  '만',
#  '봐도',
#  '인성',
#  '이',
#  '딱',
#  '보이는',
#  '그런',
#  '...',
#  '나쁜사람',
#  '에게',
#  '그',
#  '순진하시고',
#  '연약한',
#  '분',
#  '이',
#  '매번',
#  '폭언',
#  '으로',
#  '얼마나',
#  '힘드셨을까요',
#  '...',
#  '생각',
#  '만',
#  '해도',
#  '가슴',
#  '이',
#  '찢어집니다',
#  '..',
#  '그런데',
#  '그',
#  '가해자',
#  '분',
#  '은',
#  '그런',
#  '분',
#  '에게',
#  '사죄',
#  '하는',
#  '마음',
#  '도',
#  '일도',
#  '없이',
#  '언론',
#  '인터뷰',
#  '에서',
#  '아무',
#  '것',
#  '도',
#  '모른',
#  '단식',
#  '입니다',
#  '.',
#  '오히려',
#  '명예훼손',
#  '으로',
#  '맞고소',
#  '를',
#  '했다고',
#  '..',
#  '정말',
#  '인간',
#  '인가',
#  '싶습니다',
#  '.',
#  '우리',
#  '애',
#  '들',
#  '10',
#  '명',
#  '풀어서',
#  '땅',
#  '에',
#  '묻어줄',
#  '까라는',
#  '말',
#  '을',
#  '하는거',
#  '보면',
#  '조폭',
#  '관련',
#  '된',
#  '분',
#  '이실',
#  '것',
#  '같은데요',
#  ',',
#  '연예계',
#  '종사',
#  '하시는',
#  '분',
#  '매니져',
#  '일',
#  '하시던',
#  '분',
#  '이라고',
#  '들었는데',
#  '조폭',
#  '관련',
#  '일',
#  '하는',
#  '사람',
#  '이면',
#  '수',
#  '사',
#  '진행',
#  '부탁드립니다',
#  '.',
#  '기사',
#  '댓글',
#  '만',
#  '봐도',
#  '강북',
#  '하면',
#  '조폭',
#  '알아준단',
#  '식',
#  '인데',
#  '강북구',
#  '조폭',
#  '들',
#  '수사',
#  '강하게',
#  '원합니다',
#  '.',
#  '그',
#  '래야',
#  '이렇게',
#  '강',
#  '자',
#  '가',
#  '약자',
#  '를',
#  '협박',
#  '하고',
#  '폭행',
#  '하는',
#  '일이',
#  '없을',
#  '것',
#  '같습니다',
#  '.',
#  '마음',
#  '같아서는',
#  '사형',
#  '집행',
#  '해달라고',
#  '말씀드리고싶은데',
#  '..',
#  '철철',
#  '히',
#  '다',
#  '수사',
#  '해서',
#  '경비',
#  '아저씨',
#  '의',
#  '억울함을',
#  '풀어',
#  '드리고',
#  '싶습니다',
#  '.',
#  '사형',
#  '은',
#  '아니더라도',
#  '무기징역',
#  '원합니다',
#  '.',
#  '그리고',
#  '경비',
#  '아저씨',
#  '들',
#  '이나',
#  '하청',
#  '용역',
#  '분들',
#  '보호',
#  '해주세요',
#  '..',
#  '경비',
#  '아저씨',
#  '들',
#  '도',
#  '한',
#  '가정',
#  '의',
#  '사랑받는',
#  '소중한',
#  '할아버지',
#  '남편',
#  '아빠',
#  '입니다',
#  '.',
#  '입',
#  '주민',
#  '의',
#  '갑질',
#  '..',
#  '없어져야',
#  '합니다',
#  '.',
#  '오히려',
#  '아파트',
#  '를',
#  '위해',
#  '입',
#  '주민',
#  '들',
#  '을',
#  '위해',
#  '고생',
#  '하신다고',
#  '응원',
#  '을',
#  '해드려',
#  '야합니다',
#  '..',
#  '정말',
#  '좋으신',
#  '분이셨습니다',
#  '..',
#  '그',
#  '노고',
#  '를',
#  '알아서',
#  '아저씨',
#  '가',
#  '힘드신',
#  '일',
#  '당하신거',
#  '알',
#  '고',
#  '입',
#  '주민',
#  '들',
#  '이',
#  '산재',
#  '도',
#  '알아봐주시고',
#  '이번',
#  '일',
#  '벌어지고나서도',
#  '입',
#  '주민',
#  '들',
#  '이',
#  '그',
#  '분',
#  '쫒아내고',
#  '신고',
#  '하려고',
#  '희',
#  '의도',
#  '진행',
#  '했다고도',
#  '들었고',
#  ',',
#  '아저씨',
#  '가',
#  '너무',
#  '무서워하시고',
#  '스트레스',
#  '받아하시니까',
#  '병원',
#  '에도',
#  '입원',
#  '시켜',
#  '드렸다고',
#  '들었습니다',
#  '..',
#  '그만큼',
#  '열심히',
#  '사셨고',
#  '정말',
#  '순수하시고',
#  '좋은',
#  '분',
#  '이신',
#  '겁니다',
#  '.',
#  '저만',
#  '해도',
#  '문',
#  '창',
#  '과',
#  '나왔어도',
#  '글',
#  '도',
#  '잘',
#  '못',
#  '쓰고',
#  '챙피',
#  '한',
#  '마음',
#  '이지만',
#  '아저씨',
#  '가',
#  '그만큼',
#  '저',
#  '한테',
#  '잘',
#  '해주시고',
#  '열심히',
#  '해',
#  '주셨기에',
#  '안타깝고',
#  '화가',
#  '나',
#  '는',
#  '마음',
#  '에',
#  '처음',
#  '국민',
#  '청원',
#  '을',
#  '올려',
#  '봅니다',
#  '.',
#  '제발',
#  '아저씨',
#  '의',
#  '억울함을',
#  '풀어주세요',
#  '엄',
#  '한',
#  '형벌',
#  '이',
#  '나올수있게',
#  '같이',
#  '힘써주세요',
#  '.',
#  '문재인',
#  '대통령',
#  '님',
#  '부디',
#  '약자',
#  '가',
#  '강',
#  '자',
#  '에게',
#  '협박',
#  '과',
#  '폭행',
#  '을',
#  '당해서',
#  '자살',
#  '을',
#  '하는',
#  '경우',
#  '가',
#  '없는',
#  '나라',
#  '가',
#  '되게',
#  '해주십시오',
#  '̤̫',
#  '..',
#  '긴',
#  '글',
#  '읽어주셔서',
#  '감사합니다',
#  '[',
#  '본',
#  '게시',
#  '물의',
#  '일부',
#  '내용',
#  '이',
#  '국민',
#  '청원',
#  '요건',
#  '에',
#  '위배',
#  '되어',
#  '관리자',
#  '에',
#  '의해',
#  '수정',
#  '되었습니다',
#  ']',
#  '\n',
#  '생후',
#  '6',
#  '개월',
#  '의',
#  '신생아',
#  '부터',
#  '아동',
#  '에',
#  '이르기까지',
#  '광범위한',
#  '피해자',
#  '의',
#  '성',
#  '착취',
#  '동영상',
#  '을',
#  '유통',
#  '했던',
#  '다크',
#  '웹',
#  '운영자',
#  '손',
#  '모씨',
#  '가',
#  '2020년',
#  '4월',
#  '출소',
#  '예정',
#  '입니다',
#  '.',
#  '아동',
#  '청소년',
#  '성',
#  '보호',
#  '에',
#  '관',
#  '한',
#  '법률',
#  '중',
#  '“',
#  '아동',
#  '/',
#  '청소년',
#  '대상',
#  '으로',
#  '음란물',
#  '제작',
#  '및',
#  '유통',
#  '”',
#  '에',
#  '대해',
#  '서',
#  '1년',
#  '6',
#  '개월',
#  '형',
#  '을',
#  '선고',
#  '받았습니다',
#  '.',
#  '이',
#  '사실',
#  '이',
#  '알려져',
#  '30만',
#  '이',
#  '넘는',
#  '국민',
#  '이',
#  '국민',
#  '청원',
#  '을',
#  '통해',
#  '다크',
#  '웹',
#  '운영자',
#  '처벌',
#  '을',
#  '요청',
#  '했을',
#  '때',
#  ',',
#  '청와대',
#  '는',
#  '3',
#  '권',
#  '분립',
#  '을',
#  '이유',
#  '로',
#  '아무',
#  '것',
#  '도',
#  '못',
#  '한다는',
#  '무력한',
#  '답',
#  '을',
#  '주었습니다',
#  '.------------------------------------------------------------------[',
#  '관련',
#  '링크',
#  '1',
#  ']',
#  '다크',
#  '웹',
#  '운영자',
#  '를',
#  '제대로',
#  '처벌',
#  '해달라는',
#  '청와대',
#  '국민',
#  '청원',
#  ',',
#  'https://www1.president.go.kr/petitions/583190',
#  '다행',
#  '스럽게',
#  '도',
#  '손씨',
#  '를',
#  '“',
#  '제대로',
#  '”',
#  '처벌',
#  '할',
#  '다른',
#  '방법',
#  '이',
#  '있습니다',
#  '.',
#  '2019년',
#  '10월',
#  '에',
#  ',',
#  '미국',
#  '법무부',
#  '는',
#  '손씨',
#  '의',
#  '강제',
#  '송환',
#  '을',
#  '요청',
#  '했습니다',
#  '.',
#  '------------------------------------------------------------------',
#  '이미',
#  '처벌',
#  '받았기에',
#  '이중',
#  '처벌',
#  '의',
#  '문제',
#  '와',
#  '일사부재리',
#  '의',
#  '원칙',
#  '을',
#  '근거',
#  '로',
#  '우려',
#  '가',
#  '있다고',
#  '생각',
#  '할',
#  '수',
#  '있습니다',
#  '.',
#  '그러나',
#  '전문가',
#  '들',
#  '의',
#  '의견',
#  '에',
#  '따르면',
#  '미국',
#  '의',
#  '사법',
#  '당',
#  '국도',
#  '처벌',
#  '의',
#  '권한',
#  '이',
#  '있다고',
#  '합니다',
#  '.',
#  '[',
#  '관련',
#  '링크',
#  '2',
#  ']',
#  '미국',
#  '법무부',
#  '의',
#  '강제',
#  '송환',
#  '요구',
#  '에',
#  '대한',
#  '기사',
#  '중',
#  '사법',
#  '처리',
#  '가능성',
#  '에',
#  '대한',
#  '전문가',
#  '의',
#  '의견',
#  '[',
#  '출처',
#  ':',
#  '중앙',
#  '일보',
#  ']',
#  '美',
#  '법무부',
#  ',',
#  "'",
#  '아동',
#  '음란물',
#  '다크',
#  '웹',
#  "'",
#  '운영자',
#  '손씨',
#  '강제',
#  '송환',
#  '요',
#  '구https://news.joins.com/article/23614095',
#  '미국',
#  '사법',
#  '당국',
#  '이',
#  '손씨',
#  '를',
#  '미국',
#  '법',
#  '으로도',
#  '처벌',
#  '할',
#  '가능성',
#  '에',
#  '관심',
#  '이',
#  '모였지만',
#  ',',
#  '손씨',
#  '가',
#  '이미',
#  '한',
#  '국법',
#  '에',
#  '따라',
#  '처벌',
#  '을',
#  '받고',
#  '있는',
#  '상황',
#  '에서',
#  '이중',
#  '처벌',
#  '문제',
#  '와',
#  '일사부재리',
#  '원칙',
#  '에',
#  '어긋날',
#  '수',
#  '있다는',
#  '우려',
#  '가',
#  '나왔다',
#  '.',
#  '그러나',
#  '인터넷',
#  '상',
#  '에',
#  '아동',
#  '음란물',
#  '을',
#  '유포',
#  '한',
#  '손씨',
#  '의',
#  '행위',
#  '는',
#  '미국법',
#  '에도',
#  '저촉',
#  '이',
#  '되며',
#  ',',
#  '미국',
#  '의',
#  '사법',
#  '당',
#  '국도',
#  '처벌',
#  '의',
#  '권한',
#  '이',
#  '있기',
#  '때문',
#  '에',
#  '이러한',
#  '원칙',
#  '은',
#  '국가',
#  '간',
#  '에는',
#  '적용',
#  '될',
#  '수',
#  '없다는',
#  '게',
#  '전문가',
#  '들',
#  '의',
#  '분석',
#  '이다',
#  ...]

# %%
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘','하지만','결국']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='인권/성평등 청원내용')
ko.vocab().most_common(50)
# Out:
# [('피해자', 133),
#  ('가해자', 81),
#  ('여성', 75),
#  ('사람', 72),
#  ('사건', 70),
#  ('생각', 67),
#  ('처벌', 56),
#  ('국민', 54),
#  ('보호', 48),
#  ('청소년', 45),
#  ('성', 41),
#  ('아동', 40),
#  ('법', 38),
#  ('수사', 37),
#  ('범죄', 34),
#  ('피해', 33),
#  ('촬영', 32),
#  ('사진', 32),
#  ('중위', 32),
#  ('성범죄', 31),
#  ('여자', 30),
#  ('청원', 29),
#  ('이상', 29),
#  ('신랑', 29),
#  ('행위', 28),
#  ('국가', 28),
#  ('판결', 27),
#  ('성폭력', 27),
#  ('영상', 27),
#  ('경우', 26),
#  ('재판', 26),
#  ('현재', 26),
#  ('폭행', 25),
#  ('개정', 25),
#  ('경찰', 25),
#  (':', 24),
#  ('웹하드', 24),
#  ('채용', 23),
#  ('...', 22),
#  ('앞', 22),
#  ('문', 22),
#  ('기사', 22),
#  ('알', 22),
#  ('이유', 22),
#  ('가해', 22),
#  ('대한민국', 22),
#  ('협박', 21),
#  ('남성', 21),
#  ('사회', 21),
#  ('모든', 21)]

# %%
plt.figure(figsize=(15,6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data = dict(ko.vocab().most_common(150))

# %%
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',).generate_from_frequencies(data)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### 5. Word2Vec을 이용해 단어간 유사성 찾기

# %% [markdown]
# word2vec -> word to vector 이라는 뜻일듯 ㅋㅋㅋㅋ 단어간 유사성 확인하기!

# %%
import gensim 
from gensim.models import word2vec

# %%
okt = Okt()
results = []

for line in humanRights['청원내용']: 
  # 형태소 분석 
  malist = okt.pos(line, norm=True, stem=True) #쪼개버려
  #print(malist)
  r = []

  # word2vec 실행
  for word in malist: 
    if not word[1] in ['Josa', 'Eomi','punctuation']:
      r.append(word[0])

  r1 = (" ".join(r)).strip()
  results.append(r1)
  #print(r1)

# %%
data_file = 'human_rights.data'
with open(data_file, 'w', encoding='utf-8') as fp: 
  fp.write("\n".join(results)) # 저-장~

# %%
data = word2vec.LineSentence(data_file)
model = word2vec.Word2Vec(data, size=200, window=10, hs=1, min_count=2, sg=1)

model.save('human_rights.model')

# %%
model = word2vec.Word2Vec.load("human_rights.model")
# 1st 단어: 피해자
model.wv.most_similar(positive=['피해자'])
# Out:
# [('부모', 0.9389052391052246),
#  ('가해자', 0.9292822480201721),
#  ('판단', 0.9264342784881592),
#  ('학교폭력', 0.9169459939002991),
#  ('수많다', 0.9157352447509766),
#  ('위협', 0.9154412746429443),
#  ('당연하다', 0.9106940627098083),
#  ('만취', 0.9081660509109497),
#  ('증거', 0.9066944718360901),
#  ('분명하다', 0.9046844244003296)]

# %%
#2nd 단어: 가해자
model.wv.most_similar(positive=['가해자'])
# Out:
# [('위협', 0.9366914629936218),
#  ('피해자', 0.9292822480201721),
#  ('부모', 0.9272646903991699),
#  ('당당하다', 0.9254621267318726),
#  ('학교폭력', 0.916011393070221),
#  (',', 0.9149124622344971),
#  ('성폭행', 0.9114189743995667),
#  ('입장', 0.91086745262146),
#  ('자백', 0.9075099229812622),
#  ('라며', 0.9059184789657593)]

# %%
model.wv.most_similar(positive=['여성', '성범죄'])
# Out:
# [('저지르다', 0.9760609865188599),
#  ('성차별', 0.9647566080093384),
#  ('이전', 0.9641237258911133),
#  ('정부', 0.9610803127288818),
#  ('개혁', 0.9607843160629272),
#  ('생물학', 0.9586971998214722),
#  ('원인', 0.957780122756958),
#  ('블라인드', 0.9565125703811646),
#  ('자료', 0.9562168121337891),
#  ('화', 0.9553120136260986)]

# %% [markdown]
# ### 6. 과제

# %% [markdown]
# **과제 1**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

petition = pd.read_csv('Final-Blue-House-Petition-data.csv', encoding='utf-8')
pet_mem = petition['참여인원'].sort_values()
pet_mem.plot(kind='barh',grid=True,figsize=(20,20))
plt.show()

# %% [markdown]
# 바로 파일을 열어서 정렬하고 그래프를 만들면 인덱스와 같이 표시됨(주황, 파랑) 인덱스도 그래프로 표시하는줄 알고 그런듯? 그래서 따로 떼어서 만들어야함!

# %% [markdown]
# **과제 2**

# %%
from datetime import datetime
import time

petition['답변기간'] = 0
#petition.drop(['Unnamed: 0'], axis='columns',inplace=True)
    
for n in range(0,117):
    dt = datetime.strptime(petition['청원답변일'][n], '%Y. %m. %d')
    dtt = datetime.strptime(petition['청원시작일'][n], '%Y. %m. %d')
    result = dt-dtt
    petition['답변기간'][n] = result.days

print('청원 답변 기간 평균 %d일'% petition['답변기간'].mean())
# Out:
# 청원 답변 기간 평균 52
# C:\Users\Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# [str 2 datestamp 변환 계산하기](https://inma.tistory.com/96)
#
# [문자열 자료형, 포매팅](https://wikidocs.net/13)

# %%
cat = ['인권/성평등','육아/교육','문화/예술/체육/언론','기타','성장동력','보건복지','미래',
       '반려동물','정치개혁','안전/환경','교통/건축/국토','외교/통일/국방','행정','경제민주화','일자리']
#print(len(cat))
for n in cat:
    is_tmp = petition['카테고리'] == n
    tmp = petition[is_tmp]
    print(n,'평균 답변 기간 %d일' % tmp['답변기간'].mean())
# Out:
# 인권/성평등 평균 답변 기간 49일
# 육아/교육 평균 답변 기간 58일
# 문화/예술/체육/언론 평균 답변 기간 54일
# 기타 평균 답변 기간 51일
# 성장동력 평균 답변 기간 50일
# 보건복지 평균 답변 기간 49일
# 미래 평균 답변 기간 75일
# 반려동물 평균 답변 기간 45일
# 정치개혁 평균 답변 기간 52일
# 안전/환경 평균 답변 기간 55일
# 교통/건축/국토 평균 답변 기간 68일
# 외교/통일/국방 평균 답변 기간 48일
# 행정 평균 답변 기간 42일
# 경제민주화 평균 답변 기간 57일
# 일자리 평균 답변 기간 61일

# %% [markdown]
# **과제 3**

# %%
politicalreform = petition[petition['카테고리'] == '정치개혁']
politicalreform_text = ''

for each_line in politicalreform['청원내용']: 
  politicalreform_text = politicalreform_text + each_line + '\n'
tokens_ko = okt.morphs(politicalreform_text)

stop_words = ['한국','대한민국','해야','스스로','로서','으로서','서','하였습니다','이미','모든','장','.','지','바','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘','하지만','결국']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='정치개혁 청원내용')
ko.vocab().most_common(50)
# Out:
# [('국민', 74),
#  ('대통령', 30),
#  ('검찰', 30),
#  ('수사', 29),
#  ('조국', 22),
#  ('국회의원', 22),
#  ('수석', 21),
#  ('문재인', 20),
#  ('사건', 20),
#  ('생각', 17),
#  ('정부', 14),
#  ('장관', 14),
#  ('정권', 14),
#  ('인사', 14),
#  ('정치', 14),
#  ('우리', 13),
#  ('사단', 13),
#  ('합동', 11),
#  ('당', 11),
#  ('책임', 10),
#  ('공직자', 10),
#  ('입국', 9),
#  ('청원', 9),
#  ('하며', 9),
#  ('문제', 9),
#  ('의원', 9),
#  ('금지', 8),
#  ('법', 8),
#  ('현재', 8),
#  ('국회', 8),
#  ('바로', 8),
#  ('법무부', 8),
#  ('결과', 8),
#  ('자신', 8),
#  ('논란', 8),
#  ('야당', 8),
#  ('자유', 8),
#  ('사람', 7),
#  ('탄핵', 7),
#  ('총장', 7),
#  ('인물', 7),
#  ('중앙', 7),
#  ('발표', 7),
#  ('사이트', 7),
#  ('SNS', 7),
#  ('북한', 7),
#  ('중국', 6),
#  ('국내', 6),
#  ('에서는', 6),
#  ('않습니다', 6)]

# %%
data = dict(ko.vocab().most_common(150))
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',).generate_from_frequencies(data)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
