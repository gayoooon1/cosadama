# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
df_k = df[df['country'] == 'South Korea']

# %%
df_k
# Out:
#        show_id     type                        title    director  \
# 71    80187061    Movie                    The Mayor  Park In-je
# 146   81095101  TV Show                     Vagabond         NaN
# 190   81144925  TV Show     When the Camellia Blooms         NaN
# 285   81011508  TV Show                         Life         NaN
# 443   81161487  TV Show      My Country: The New Age         NaN
# ...        ...      ...                          ...         ...
# 6135  80176931  TV Show             Chef & My Fridge         NaN
# 6181  80175275  TV Show                      Vroomiz         NaN
# 6182  80176842  TV Show             Men on a Mission  Jung-ah Im
# 6202  80116626  TV Show                 The Cravings         NaN
# 6205  80036747  TV Show  Pororo - The Little Penguin         NaN
#
#                                                    cast      country  \
# 71    Min-sik Choi, Do-won Kwak, Eun-kyung Shim, So-...  South Korea
# ...
